# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request
from collections import Counter
from konlpy.tag import Mecab
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import MeCab
m = MeCab.Tagger()

urllib.request.urlretrieve("https://raw.githubusercontent.com/bab2min/corpus/master/sentiment/naver_shopping.txt", filename="ratings_total.txt")
total_data = pd.read_table('ratings_total.txt', names=['ratings', 'reviews'])

# 레이블 만들기 (평점이 4~5인 리유에는 레이블 1을, 평점이 1~2인 리뷰는 레이블 0을 부여)
total_data['label'] = np.select([total_data.ratings > 3], [1], default=0)

# 각 열에 대해서 중복을 제외한 샘플의 수를 카운트
total_data['ratings'].nunique(), total_data['reviews'].nunique(), total_data['label'].nunique()

# reviews 열에서 중복인 내용이 있다면 중복 제거
total_data.drop_duplicates(subset=['reviews'], inplace=True)

# 훈련 데이터와 테스트 데이터를 3:1 비율로 분리
train_data, test_data = train_test_split(total_data, test_size = 0.25, random_state = 42)


# 데이터 정제하기
# 트레인 데이터 한글과 공백을 제외하고 모두 제거
train_data['reviews'] = train_data['reviews'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
train_data['reviews'].replace('', np.nan, inplace=True)


# 테스트 데이터
test_data.drop_duplicates(subset = ['reviews'], inplace=True) # 중복 제거
test_data['reviews'] = test_data['reviews'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
test_data['reviews'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
test_data = test_data.dropna(how='any') # Null 값 제거


# 토큰화
mecab = Mecab(dicpath=r"C:/mecab/mecab-ko-dic")


stopwords = ['도', '는', '다', '의', '가', '이', '은', '한', '에', '하', '고', '을', '를', '인', '듯', '과', '와', '네', '들', '듯', '지', '임', '게']


train_data['tokenized'] = train_data['reviews'].apply(mecab.morphs)
train_data['tokenized'] = train_data['tokenized'].apply(lambda x: [item for item in x if item not in stopwords])


test_data['tokenized'] = test_data['reviews'].apply(mecab.morphs)
test_data['tokenized'] = test_data['tokenized'].apply(lambda x: [item for item in x if item not in stopwords])


negative_words = np.hstack(train_data[train_data.label == 0]['tokenized'].values)
positive_words = np.hstack(train_data[train_data.label == 1]['tokenized'].values)

# 부정 리뷰에서 주로 등장하는 것들
negative_word_count = Counter(negative_words)
# 긍정 리뷰에서 주로 등장하는 것들
positive_word_count = Counter(positive_words)


X_train = train_data['tokenized'].values
y_train = train_data['label'].values
X_test= test_data['tokenized'].values
y_test = test_data['label'].values


tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)


threshold = 2
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value


vocab_size = total_cnt - rare_cnt + 2

tokenizer = Tokenizer(vocab_size, oov_token = 'OOV') 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)


def below_threshold_len(max_len, nested_list):
  count = 0
  for sentence in nested_list:
    if(len(sentence) <= max_len):
        count = count + 1


max_len = 80
below_threshold_len(max_len, X_train)


X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)



from tensorflow.keras.layers import Embedding, Dense, GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

embedding_dim = 100
hidden_units = 128

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(GRU(hidden_units))
model.add(Dense(1, activation='sigmoid'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=15, callbacks=[es, mc], batch_size=64, validation_split=0.2)



loaded_model = load_model('best_model.h5')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19068\1979997429.py in <module>
#      14
#      15 urllib.request.urlretrieve("https://raw.githubusercontent.com/bab2min/corpus/master/sentiment/naver_shopping.txt", filename="ratings_total.txt")
# ---> 16 total_data = pd.read_table('ratings_total.txt', names=['ratings', 'reviews'])
#      17
#      18 # 레이블 만들기 (평점이 4~5인 리유에는 레이블 1을, 평점이 1~2인 리뷰는 레이블 0을 부여)
#
# c:\Users\82108\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\82108\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers\readers.py in read_table(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, encoding_errors, delim_whitespace, low_memory, memory_map, float_precision)
#     681     kwds.update(kwds_defaults)
#     682
# --> 683     return _read(filepath_or_buffer, kwds)
#     684
#     685
#
# c:\Users\82108\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# c:\Users\82108\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# c:\Users\82108\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     222         try:
#     223             if self.low_memory:
# --> 224                 chunks = self._reader.read_low_memory(nrows)
#     225                 # destructive to chunks
#     226                 data = _concatenate_chunks(chunks)
#
# c:\Users\82108\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# c:\Users\82108\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# c:\Users\82108\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# c:\Users\82108\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xeb in position 529514: invalid continuation byte

# %%
# 감성 분석
new_review = pd.read_csv(r'C:\Users\82108\Coding\MZ-trend\트위터\클린디 트위터 로우 데이터\치아미백 전처리.csv')
new_review = new_review.dropna(axis=0)
new_review = new_review.drop_duplicates()

def sentiment_predict(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  new_sentence = mecab.morphs(new_sentence)
  new_sentence = [word for word in new_sentence if not word in stopwords]
  encoded = tokenizer.texts_to_sequences([new_sentence])
  pad_new = pad_sequences(encoded, maxlen = max_len)

  score = float(loaded_model.predict(pad_new))
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정^^ 리뷰입니다.".format(score * 100))
    return ("{:.2f} 1".format(score * 100))
  else:
    print("{:.2f}% 확률로 부정!! 리뷰입니다.".format((1 - score) * 100))
    return ("{:.2f} 2".format((1 - score) * 100))
  
new_review['감성분석'] = new_review['내용'].apply(lambda x:sentiment_predict(x))
new_review.to_csv(r'C:\Users\82108\Coding\MZ-trend\트위터\클린디 트위터 로우 데이터\치아미백 감성분석.csv', encoding = 'utf-8-sig')








new_review = pd.read_csv(r'C:\Users\82108\Coding\MZ-trend\트위터\클린디 트위터 로우 데이터\치주염 전처리.csv')
new_review = new_review.dropna(axis=0)
new_review = new_review.drop_duplicates()

def sentiment_predict(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  new_sentence = mecab.morphs(new_sentence)
  new_sentence = [word for word in new_sentence if not word in stopwords]
  encoded = tokenizer.texts_to_sequences([new_sentence])
  pad_new = pad_sequences(encoded, maxlen = max_len)

  score = float(loaded_model.predict(pad_new))
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정^^ 리뷰입니다.".format(score * 100))
    return ("{:.2f} 1".format(score * 100))
  else:
    print("{:.2f}% 확률로 부정!! 리뷰입니다.".format((1 - score) * 100))
    return ("{:.2f} 2".format((1 - score) * 100))
  
new_review['감성분석'] = new_review['내용'].apply(lambda x:sentiment_predict(x))
new_review.to_csv(r'C:\Users\82108\Coding\MZ-trend\트위터\클린디 트위터 로우 데이터\치주염 감성분석.csv', encoding = 'utf-8-sig')







new_review = pd.read_csv(r'C:\Users\82108\Coding\MZ-trend\트위터\클린디 트위터 로우 데이터\구내염 전처리.csv')
new_review = new_review.dropna(axis=0)
new_review = new_review.drop_duplicates()

def sentiment_predict(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  new_sentence = mecab.morphs(new_sentence)
  new_sentence = [word for word in new_sentence if not word in stopwords]
  encoded = tokenizer.texts_to_sequences([new_sentence])
  pad_new = pad_sequences(encoded, maxlen = max_len)

  score = float(loaded_model.predict(pad_new))
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정^^ 리뷰입니다.".format(score * 100))
    return ("{:.2f} 1".format(score * 100))
  else:
    print("{:.2f}% 확률로 부정!! 리뷰입니다.".format((1 - score) * 100))
    return ("{:.2f} 2".format((1 - score) * 100))
  
new_review['감성분석'] = new_review['내용'].apply(lambda x:sentiment_predict(x))
new_review.to_csv(r'C:\Users\82108\Coding\MZ-trend\트위터\클린디 트위터 로우 데이터\구내염 감성분석.csv', encoding = 'utf-8-sig')
# Out:
# 70.93% 확률로 부정!! 리뷰입니다.
# 91.47% 확률로 부정!! 리뷰입니다.
# 95.30% 확률로 긍정^^ 리뷰입니다.
# 77.50% 확률로 부정!! 리뷰입니다.
# 69.27% 확률로 부정!! 리뷰입니다.
# 71.36% 확률로 부정!! 리뷰입니다.
# 94.86% 확률로 부정!! 리뷰입니다.
# 99.30% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 59.20% 확률로 부정!! 리뷰입니다.
# 88.02% 확률로 긍정^^ 리뷰입니다.
# 99.28% 확률로 부정!! 리뷰입니다.
# 59.41% 확률로 부정!! 리뷰입니다.
# 60.17% 확률로 부정!! 리뷰입니다.
# 92.76% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 85.09% 확률로 부정!! 리뷰입니다.
# 89.71% 확률로 부정!! 리뷰입니다.
# 90.89% 확률로 긍정^^ 리뷰입니다.
# 91.16% 확률로 부정!! 리뷰입니다.
# 87.21% 확률로 부정!! 리뷰입니다.
# 74.68% 확률로 부정!! 리뷰입니다.
# 64.28% 확률로 부정!! 리뷰입니다.
# 79.76% 확률로 부정!! 리뷰입니다.
# 54.01% 확률로 부정!! 리뷰입니다.
# 60.70% 확률로 부정!! 리뷰입니다.
# 68.03% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 53.73% 확률로 부정!! 리뷰입니다.
# 55.35% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 52.84% 확률로 긍정^^ 리뷰입니다.
# 76.22% 확률로 부정!! 리뷰입니다.
# 67.67% 확률로 긍정^^ 리뷰입니다.
# 67.67% 확률로 긍정^^ 리뷰입니다.
# 65.93% 확률로 부정!! 리뷰입니다.
# 74.70% 확률로 부정!! 리뷰입니다.
# 79.83% 확률로 부정!! 리뷰입니다.
# 97.41% 확률로 긍정^^ 리뷰입니다.
# 57.82% 확률로 부정!! 리뷰입니다.
# 57.82% 확률로 부정!! 리뷰입니다.
# 67.45% 확률로 부정!! 리뷰입니다.
# 92.21% 확률로 부정!! 리뷰입니다.
# 57.58% 확률로 긍정^^ 리뷰입니다.
# 84.22% 확률로 부정!! 리뷰입니다.
# 98.91% 확률로 부정!! 리뷰입니다.
# 57.23% 확률로 부정!! 리뷰입니다.
# 58.50% 확률로 긍정^^ 리뷰입니다.
# 75.76% 확률로 부정!! 리뷰입니다.
# 70.23% 확률로 부정!! 리뷰입니다.
# 98.09% 확률로 부정!! 리뷰입니다.
# 95.29% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 65.93% 확률로 부정!! 리뷰입니다.
# 77.64% 확률로 부정!! 리뷰입니다.
# 79.83% 확률로 부정!! 리뷰입니다.
# 71.43% 확률로 부정!! 리뷰입니다.
# 63.08% 확률로 긍정^^ 리뷰입니다.
# 94.72% 확률로 부정!! 리뷰입니다.
# 87.80% 확률로 부정!! 리뷰입니다.
# 73.55% 확률로 부정!! 리뷰입니다.
# 73.51% 확률로 긍정^^ 리뷰입니다.
# 75.87% 확률로 긍정^^ 리뷰입니다.
# 65.43% 확률로 부정!! 리뷰입니다.
# 96.44% 확률로 부정!! 리뷰입니다.
# 93.03% 확률로 부정!! 리뷰입니다.
# 99.15% 확률로 긍정^^ 리뷰입니다.
# 95.23% 확률로 부정!! 리뷰입니다.
# 86.63% 확률로 부정!! 리뷰입니다.
# 91.93% 확률로 부정!! 리뷰입니다.
# 67.35% 확률로 부정!! 리뷰입니다.
# 81.02% 확률로 부정!! 리뷰입니다.
# 69.38% 확률로 부정!! 리뷰입니다.
# 76.61% 확률로 긍정^^ 리뷰입니다.
# 60.82% 확률로 긍정^^ 리뷰입니다.
# 67.92% 확률로 부정!! 리뷰입니다.
# 69.15% 확률로 부정!! 리뷰입니다.
# 81.24% 확률로 긍정^^ 리뷰입니다.
# 97.08% 확률로 부정!! 리뷰입니다.
# 97.03% 확률로 긍정^^ 리뷰입니다.
# 68.53% 확률로 긍정^^ 리뷰입니다.
# 86.40% 확률로 부정!! 리뷰입니다.
# 75.13% 확률로 부정!! 리뷰입니다.
# 81.29% 확률로 부정!! 리뷰입니다.
# 58.74% 확률로 부정!! 리뷰입니다.
# 59.53% 확률로 긍정^^ 리뷰입니다.
# 52.47% 확률로 부정!! 리뷰입니다.
# 72.44% 확률로 부정!! 리뷰입니다.
# 82.99% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 54.12% 확률로 부정!! 리뷰입니다.
# 96.81% 확률로 부정!! 리뷰입니다.
# 91.49% 확률로 부정!! 리뷰입니다.
# 96.01% 확률로 부정!! 리뷰입니다.
# 96.56% 확률로 긍정^^ 리뷰입니다.
# 96.73% 확률로 부정!! 리뷰입니다.
# 76.80% 확률로 긍정^^ 리뷰입니다.
# 97.25% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 90.15% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 54.53% 확률로 긍정^^ 리뷰입니다.
# 78.65% 확률로 부정!! 리뷰입니다.
# 57.90% 확률로 부정!! 리뷰입니다.
# 51.30% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 85.52% 확률로 긍정^^ 리뷰입니다.
# 97.73% 확률로 부정!! 리뷰입니다.
# 79.14% 확률로 부정!! 리뷰입니다.
# 94.10% 확률로 부정!! 리뷰입니다.
# 97.93% 확률로 부정!! 리뷰입니다.
# 91.08% 확률로 긍정^^ 리뷰입니다.
# 83.50% 확률로 부정!! 리뷰입니다.
# 66.33% 확률로 부정!! 리뷰입니다.
# 82.92% 확률로 부정!! 리뷰입니다.
# 66.26% 확률로 부정!! 리뷰입니다.
# 88.89% 확률로 부정!! 리뷰입니다.
# 68.20% 확률로 부정!! 리뷰입니다.
# 50.77% 확률로 부정!! 리뷰입니다.
# 99.21% 확률로 부정!! 리뷰입니다.
# 96.52% 확률로 긍정^^ 리뷰입니다.
# 58.19% 확률로 긍정^^ 리뷰입니다.
# 93.61% 확률로 부정!! 리뷰입니다.
# 88.40% 확률로 부정!! 리뷰입니다.
# 77.53% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 87.55% 확률로 부정!! 리뷰입니다.
# 50.58% 확률로 부정!! 리뷰입니다.
# 72.87% 확률로 부정!! 리뷰입니다.
# 99.20% 확률로 부정!! 리뷰입니다.
# 52.36% 확률로 부정!! 리뷰입니다.
# 97.21% 확률로 긍정^^ 리뷰입니다.
# 84.78% 확률로 부정!! 리뷰입니다.
# 67.84% 확률로 부정!! 리뷰입니다.
# 85.07% 확률로 부정!! 리뷰입니다.
# 91.92% 확률로 부정!! 리뷰입니다.
# 96.66% 확률로 부정!! 리뷰입니다.
# 65.86% 확률로 부정!! 리뷰입니다.
# 90.66% 확률로 부정!! 리뷰입니다.
# 65.61% 확률로 긍정^^ 리뷰입니다.
# 51.63% 확률로 긍정^^ 리뷰입니다.
# 71.65% 확률로 긍정^^ 리뷰입니다.
# 74.29% 확률로 부정!! 리뷰입니다.
# 90.14% 확률로 부정!! 리뷰입니다.
# 85.64% 확률로 부정!! 리뷰입니다.
# 64.09% 확률로 부정!! 리뷰입니다.
# 84.05% 확률로 부정!! 리뷰입니다.
# 93.10% 확률로 부정!! 리뷰입니다.
# 75.13% 확률로 부정!! 리뷰입니다.
# 86.62% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 96.96% 확률로 부정!! 리뷰입니다.
# 55.61% 확률로 부정!! 리뷰입니다.
# 71.51% 확률로 긍정^^ 리뷰입니다.
# 64.16% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 79.69% 확률로 부정!! 리뷰입니다.
# 91.10% 확률로 부정!! 리뷰입니다.
# 68.64% 확률로 부정!! 리뷰입니다.
# 94.98% 확률로 부정!! 리뷰입니다.
# 97.35% 확률로 부정!! 리뷰입니다.
# 98.52% 확률로 부정!! 리뷰입니다.
# 91.08% 확률로 부정!! 리뷰입니다.
# 55.37% 확률로 긍정^^ 리뷰입니다.
# 52.46% 확률로 부정!! 리뷰입니다.
# 62.09% 확률로 부정!! 리뷰입니다.
# 51.01% 확률로 부정!! 리뷰입니다.
# 95.22% 확률로 부정!! 리뷰입니다.
# 68.27% 확률로 부정!! 리뷰입니다.
# 88.87% 확률로 부정!! 리뷰입니다.
# 90.97% 확률로 긍정^^ 리뷰입니다.
# 84.33% 확률로 긍정^^ 리뷰입니다.
# 59.88% 확률로 부정!! 리뷰입니다.
# 98.85% 확률로 부정!! 리뷰입니다.
# 68.37% 확률로 부정!! 리뷰입니다.
# 82.21% 확률로 긍정^^ 리뷰입니다.
# 67.99% 확률로 부정!! 리뷰입니다.
# 97.04% 확률로 부정!! 리뷰입니다.
# 94.88% 확률로 부정!! 리뷰입니다.
# 90.63% 확률로 부정!! 리뷰입니다.
# 82.14% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 97.75% 확률로 부정!! 리뷰입니다.
# 69.90% 확률로 부정!! 리뷰입니다.
# 67.90% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 83.51% 확률로 부정!! 리뷰입니다.
# 74.05% 확률로 부정!! 리뷰입니다.
# 90.09% 확률로 부정!! 리뷰입니다.
# 62.71% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 94.44% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 80.85% 확률로 부정!! 리뷰입니다.
# 57.16% 확률로 부정!! 리뷰입니다.
# 86.72% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 91.70% 확률로 부정!! 리뷰입니다.
# 95.34% 확률로 부정!! 리뷰입니다.
# 67.41% 확률로 부정!! 리뷰입니다.
# 85.46% 확률로 부정!! 리뷰입니다.
# 62.57% 확률로 긍정^^ 리뷰입니다.
# 68.37% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 83.90% 확률로 부정!! 리뷰입니다.
# 88.50% 확률로 부정!! 리뷰입니다.
# 56.53% 확률로 부정!! 리뷰입니다.
# 72.15% 확률로 긍정^^ 리뷰입니다.
# 83.22% 확률로 긍정^^ 리뷰입니다.
# 96.46% 확률로 부정!! 리뷰입니다.
# 60.62% 확률로 부정!! 리뷰입니다.
# 89.57% 확률로 긍정^^ 리뷰입니다.
# 84.60% 확률로 부정!! 리뷰입니다.
# 73.92% 확률로 부정!! 리뷰입니다.
# 84.14% 확률로 부정!! 리뷰입니다.
# 75.69% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 51.61% 확률로 긍정^^ 리뷰입니다.
# 85.50% 확률로 부정!! 리뷰입니다.
# 63.09% 확률로 긍정^^ 리뷰입니다.
# 98.15% 확률로 긍정^^ 리뷰입니다.
# 92.23% 확률로 부정!! 리뷰입니다.
# 76.60% 확률로 부정!! 리뷰입니다.
# 58.78% 확률로 부정!! 리뷰입니다.
# 82.92% 확률로 긍정^^ 리뷰입니다.
# 52.20% 확률로 긍정^^ 리뷰입니다.
# 87.82% 확률로 긍정^^ 리뷰입니다.
# 88.53% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 80.64% 확률로 부정!! 리뷰입니다.
# 98.43% 확률로 부정!! 리뷰입니다.
# 92.53% 확률로 긍정^^ 리뷰입니다.
# 66.00% 확률로 부정!! 리뷰입니다.
# 97.50% 확률로 긍정^^ 리뷰입니다.
# 65.86% 확률로 부정!! 리뷰입니다.
# 94.79% 확률로 부정!! 리뷰입니다.
# 63.98% 확률로 부정!! 리뷰입니다.
# 65.66% 확률로 부정!! 리뷰입니다.
# 65.86% 확률로 부정!! 리뷰입니다.
# 62.33% 확률로 부정!! 리뷰입니다.
# 82.60% 확률로 부정!! 리뷰입니다.
# 96.42% 확률로 부정!! 리뷰입니다.
# 90.59% 확률로 부정!! 리뷰입니다.
# 58.98% 확률로 부정!! 리뷰입니다.
# 64.59% 확률로 긍정^^ 리뷰입니다.
# 98.44% 확률로 긍정^^ 리뷰입니다.
# 68.10% 확률로 부정!! 리뷰입니다.
# 73.09% 확률로 부정!! 리뷰입니다.
# 93.74% 확률로 부정!! 리뷰입니다.
# 89.69% 확률로 부정!! 리뷰입니다.
# 72.14% 확률로 부정!! 리뷰입니다.
# 82.91% 확률로 부정!! 리뷰입니다.
# 70.63% 확률로 부정!! 리뷰입니다.
# 70.63% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 98.63% 확률로 부정!! 리뷰입니다.
# 65.86% 확률로 부정!! 리뷰입니다.
# 57.44% 확률로 부정!! 리뷰입니다.
# 91.81% 확률로 부정!! 리뷰입니다.
# 59.00% 확률로 긍정^^ 리뷰입니다.
# 93.04% 확률로 부정!! 리뷰입니다.
# 54.46% 확률로 긍정^^ 리뷰입니다.
# 53.16% 확률로 긍정^^ 리뷰입니다.
# 62.49% 확률로 긍정^^ 리뷰입니다.
# 99.39% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 87.51% 확률로 부정!! 리뷰입니다.
# 84.97% 확률로 부정!! 리뷰입니다.
# 94.33% 확률로 부정!! 리뷰입니다.
# 95.52% 확률로 부정!! 리뷰입니다.
# 66.96% 확률로 긍정^^ 리뷰입니다.
# 78.20% 확률로 긍정^^ 리뷰입니다.
# 92.55% 확률로 긍정^^ 리뷰입니다.
# 64.83% 확률로 부정!! 리뷰입니다.
# 92.15% 확률로 부정!! 리뷰입니다.
# 95.11% 확률로 긍정^^ 리뷰입니다.
# 94.71% 확률로 부정!! 리뷰입니다.
# 94.38% 확률로 부정!! 리뷰입니다.
# 78.41% 확률로 긍정^^ 리뷰입니다.
# 97.36% 확률로 부정!! 리뷰입니다.
# 58.66% 확률로 부정!! 리뷰입니다.
# 83.61% 확률로 부정!! 리뷰입니다.
# 91.71% 확률로 부정!! 리뷰입니다.
# 81.03% 확률로 부정!! 리뷰입니다.
# 87.51% 확률로 긍정^^ 리뷰입니다.
# 79.30% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 76.86% 확률로 부정!! 리뷰입니다.
# 94.77% 확률로 부정!! 리뷰입니다.
# 92.55% 확률로 부정!! 리뷰입니다.
# 86.24% 확률로 부정!! 리뷰입니다.
# 94.88% 확률로 부정!! 리뷰입니다.
# 87.90% 확률로 부정!! 리뷰입니다.
# 86.41% 확률로 부정!! 리뷰입니다.
# 94.88% 확률로 부정!! 리뷰입니다.
# 82.27% 확률로 부정!! 리뷰입니다.
# 95.40% 확률로 부정!! 리뷰입니다.
# 73.95% 확률로 부정!! 리뷰입니다.
# 59.88% 확률로 부정!! 리뷰입니다.
# 66.88% 확률로 부정!! 리뷰입니다.
# 96.32% 확률로 부정!! 리뷰입니다.
# 94.24% 확률로 부정!! 리뷰입니다.
# 60.86% 확률로 긍정^^ 리뷰입니다.
# 50.81% 확률로 부정!! 리뷰입니다.
# 60.86% 확률로 긍정^^ 리뷰입니다.
# 82.66% 확률로 긍정^^ 리뷰입니다.
# 60.84% 확률로 부정!! 리뷰입니다.
# 76.66% 확률로 긍정^^ 리뷰입니다.
# 63.77% 확률로 긍정^^ 리뷰입니다.
# 90.25% 확률로 부정!! 리뷰입니다.
# 71.09% 확률로 부정!! 리뷰입니다.
# 54.31% 확률로 긍정^^ 리뷰입니다.
# 84.30% 확률로 부정!! 리뷰입니다.
# 92.95% 확률로 부정!! 리뷰입니다.
# 98.53% 확률로 긍정^^ 리뷰입니다.
# 75.10% 확률로 부정!! 리뷰입니다.
# 63.67% 확률로 부정!! 리뷰입니다.
# 92.75% 확률로 긍정^^ 리뷰입니다.
# 89.12% 확률로 부정!! 리뷰입니다.
# 50.85% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 55.12% 확률로 부정!! 리뷰입니다.
# 81.36% 확률로 부정!! 리뷰입니다.
# 56.19% 확률로 부정!! 리뷰입니다.
# 92.13% 확률로 부정!! 리뷰입니다.
# 91.20% 확률로 긍정^^ 리뷰입니다.
# 68.90% 확률로 부정!! 리뷰입니다.
# 68.56% 확률로 긍정^^ 리뷰입니다.
# 93.96% 확률로 부정!! 리뷰입니다.
# 52.62% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 94.00% 확률로 부정!! 리뷰입니다.
# 94.08% 확률로 긍정^^ 리뷰입니다.
# 90.13% 확률로 부정!! 리뷰입니다.
# 66.10% 확률로 부정!! 리뷰입니다.
# 92.50% 확률로 부정!! 리뷰입니다.
# 99.77% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 79.92% 확률로 부정!! 리뷰입니다.
# 99.47% 확률로 긍정^^ 리뷰입니다.
# 52.48% 확률로 긍정^^ 리뷰입니다.
# 54.38% 확률로 긍정^^ 리뷰입니다.
# 54.95% 확률로 긍정^^ 리뷰입니다.
# 98.52% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 96.93% 확률로 부정!! 리뷰입니다.
# 99.21% 확률로 부정!! 리뷰입니다.
# 95.11% 확률로 부정!! 리뷰입니다.
# 69.48% 확률로 부정!! 리뷰입니다.
# 75.59% 확률로 긍정^^ 리뷰입니다.
# 96.14% 확률로 부정!! 리뷰입니다.
# 65.42% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 92.94% 확률로 부정!! 리뷰입니다.
# 65.86% 확률로 부정!! 리뷰입니다.
# 99.25% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 96.14% 확률로 부정!! 리뷰입니다.
# 94.25% 확률로 부정!! 리뷰입니다.
# 69.48% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 52.77% 확률로 부정!! 리뷰입니다.
# 66.23% 확률로 부정!! 리뷰입니다.
# 93.91% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 95.10% 확률로 부정!! 리뷰입니다.
# 79.61% 확률로 부정!! 리뷰입니다.
# 74.57% 확률로 부정!! 리뷰입니다.
# 76.18% 확률로 부정!! 리뷰입니다.
# 88.49% 확률로 긍정^^ 리뷰입니다.
# 94.44% 확률로 부정!! 리뷰입니다.
# 91.48% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 81.12% 확률로 부정!! 리뷰입니다.
# 73.82% 확률로 긍정^^ 리뷰입니다.
# 71.74% 확률로 부정!! 리뷰입니다.
# 85.96% 확률로 부정!! 리뷰입니다.
# 87.39% 확률로 긍정^^ 리뷰입니다.
# 97.02% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.63% 확률로 부정!! 리뷰입니다.
# 96.44% 확률로 긍정^^ 리뷰입니다.
# 96.05% 확률로 부정!! 리뷰입니다.
# 66.20% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 84.85% 확률로 긍정^^ 리뷰입니다.
# 79.77% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 55.30% 확률로 부정!! 리뷰입니다.
# 73.74% 확률로 긍정^^ 리뷰입니다.
# 96.49% 확률로 부정!! 리뷰입니다.
# 95.58% 확률로 부정!! 리뷰입니다.
# 52.15% 확률로 부정!! 리뷰입니다.
# 80.47% 확률로 부정!! 리뷰입니다.
# 97.27% 확률로 부정!! 리뷰입니다.
# 86.62% 확률로 긍정^^ 리뷰입니다.
# 57.60% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 92.79% 확률로 부정!! 리뷰입니다.
# 66.02% 확률로 긍정^^ 리뷰입니다.
# 65.27% 확률로 부정!! 리뷰입니다.
# 62.67% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 86.12% 확률로 부정!! 리뷰입니다.
# 52.47% 확률로 부정!! 리뷰입니다.
# 93.62% 확률로 부정!! 리뷰입니다.
# 81.91% 확률로 부정!! 리뷰입니다.
# 74.21% 확률로 부정!! 리뷰입니다.
# 87.57% 확률로 부정!! 리뷰입니다.
# 98.68% 확률로 부정!! 리뷰입니다.
# 87.41% 확률로 긍정^^ 리뷰입니다.
# 58.00% 확률로 부정!! 리뷰입니다.
# 66.14% 확률로 부정!! 리뷰입니다.
# 68.99% 확률로 긍정^^ 리뷰입니다.
# 87.98% 확률로 부정!! 리뷰입니다.
# 87.45% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 55.35% 확률로 부정!! 리뷰입니다.
# 75.86% 확률로 긍정^^ 리뷰입니다.
# 67.43% 확률로 긍정^^ 리뷰입니다.
# 82.39% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 87.86% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.76% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 76.25% 확률로 부정!! 리뷰입니다.
# 97.61% 확률로 부정!! 리뷰입니다.
# 84.89% 확률로 부정!! 리뷰입니다.
# 92.72% 확률로 부정!! 리뷰입니다.
# 88.92% 확률로 부정!! 리뷰입니다.
# 96.88% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 64.84% 확률로 부정!! 리뷰입니다.
# 74.36% 확률로 부정!! 리뷰입니다.
# 90.98% 확률로 부정!! 리뷰입니다.
# 82.92% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 65.11% 확률로 부정!! 리뷰입니다.
# 77.89% 확률로 부정!! 리뷰입니다.
# 57.93% 확률로 긍정^^ 리뷰입니다.
# 54.67% 확률로 부정!! 리뷰입니다.
# 51.93% 확률로 부정!! 리뷰입니다.
# 72.01% 확률로 부정!! 리뷰입니다.
# 84.89% 확률로 부정!! 리뷰입니다.
# 84.89% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 72.44% 확률로 부정!! 리뷰입니다.
# 92.73% 확률로 부정!! 리뷰입니다.
# 89.00% 확률로 부정!! 리뷰입니다.
# 94.80% 확률로 부정!! 리뷰입니다.
# 96.68% 확률로 긍정^^ 리뷰입니다.
# 68.13% 확률로 부정!! 리뷰입니다.
# 91.53% 확률로 부정!! 리뷰입니다.
# 78.65% 확률로 부정!! 리뷰입니다.
# 85.31% 확률로 부정!! 리뷰입니다.
# 85.69% 확률로 부정!! 리뷰입니다.
# 96.27% 확률로 부정!! 리뷰입니다.
# 70.63% 확률로 부정!! 리뷰입니다.
# 89.26% 확률로 부정!! 리뷰입니다.
# 56.82% 확률로 긍정^^ 리뷰입니다.
# 90.89% 확률로 부정!! 리뷰입니다.
# 87.38% 확률로 부정!! 리뷰입니다.
# 81.29% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 57.14% 확률로 긍정^^ 리뷰입니다.
# 92.14% 확률로 부정!! 리뷰입니다.
# 70.99% 확률로 부정!! 리뷰입니다.
# 64.10% 확률로 긍정^^ 리뷰입니다.
# 79.71% 확률로 부정!! 리뷰입니다.
# 93.23% 확률로 부정!! 리뷰입니다.
# 78.27% 확률로 부정!! 리뷰입니다.
# 97.16% 확률로 부정!! 리뷰입니다.
# 92.15% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 65.86% 확률로 부정!! 리뷰입니다.
# 95.42% 확률로 긍정^^ 리뷰입니다.
# 70.60% 확률로 긍정^^ 리뷰입니다.
# 99.13% 확률로 부정!! 리뷰입니다.
# 95.99% 확률로 부정!! 리뷰입니다.
# 53.19% 확률로 부정!! 리뷰입니다.
# 65.83% 확률로 부정!! 리뷰입니다.
# 68.56% 확률로 부정!! 리뷰입니다.
# 79.15% 확률로 부정!! 리뷰입니다.
# 55.51% 확률로 긍정^^ 리뷰입니다.
# 51.46% 확률로 부정!! 리뷰입니다.
# 82.19% 확률로 부정!! 리뷰입니다.
# 82.37% 확률로 부정!! 리뷰입니다.
# 92.28% 확률로 부정!! 리뷰입니다.
# 87.94% 확률로 부정!! 리뷰입니다.
# 79.94% 확률로 긍정^^ 리뷰입니다.
# 99.60% 확률로 긍정^^ 리뷰입니다.
# 86.99% 확률로 부정!! 리뷰입니다.
# 60.42% 확률로 부정!! 리뷰입니다.
# 91.17% 확률로 부정!! 리뷰입니다.
# 96.90% 확률로 부정!! 리뷰입니다.
# 87.19% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 97.91% 확률로 긍정^^ 리뷰입니다.
# 83.43% 확률로 부정!! 리뷰입니다.
# 81.67% 확률로 부정!! 리뷰입니다.
# 75.69% 확률로 부정!! 리뷰입니다.
# 78.65% 확률로 부정!! 리뷰입니다.
# 89.79% 확률로 부정!! 리뷰입니다.
# 94.83% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 69.99% 확률로 부정!! 리뷰입니다.
# 91.87% 확률로 부정!! 리뷰입니다.
# 89.81% 확률로 부정!! 리뷰입니다.
# 77.81% 확률로 부정!! 리뷰입니다.
# 85.08% 확률로 부정!! 리뷰입니다.
# 60.93% 확률로 긍정^^ 리뷰입니다.
# 95.04% 확률로 부정!! 리뷰입니다.
# 52.72% 확률로 긍정^^ 리뷰입니다.
# 71.78% 확률로 부정!! 리뷰입니다.
# 88.28% 확률로 부정!! 리뷰입니다.
# 72.45% 확률로 부정!! 리뷰입니다.
# 76.09% 확률로 긍정^^ 리뷰입니다.
# 74.99% 확률로 긍정^^ 리뷰입니다.
# 76.91% 확률로 긍정^^ 리뷰입니다.
# 84.86% 확률로 긍정^^ 리뷰입니다.
# 90.33% 확률로 부정!! 리뷰입니다.
# 95.63% 확률로 부정!! 리뷰입니다.
# 66.51% 확률로 부정!! 리뷰입니다.
# 68.12% 확률로 부정!! 리뷰입니다.
# 90.65% 확률로 긍정^^ 리뷰입니다.
# 75.41% 확률로 긍정^^ 리뷰입니다.
# 85.18% 확률로 부정!! 리뷰입니다.
# 60.88% 확률로 부정!! 리뷰입니다.
# 89.10% 확률로 부정!! 리뷰입니다.
# 64.87% 확률로 부정!! 리뷰입니다.
# 69.52% 확률로 긍정^^ 리뷰입니다.
# 94.76% 확률로 부정!! 리뷰입니다.
# 68.28% 확률로 부정!! 리뷰입니다.
# 87.38% 확률로 부정!! 리뷰입니다.
# 95.90% 확률로 부정!! 리뷰입니다.
# 98.12% 확률로 부정!! 리뷰입니다.
# 92.62% 확률로 부정!! 리뷰입니다.
# 88.19% 확률로 부정!! 리뷰입니다.
# 72.52% 확률로 부정!! 리뷰입니다.
# 77.80% 확률로 부정!! 리뷰입니다.
# 93.14% 확률로 부정!! 리뷰입니다.
# 70.12% 확률로 부정!! 리뷰입니다.
# 92.49% 확률로 부정!! 리뷰입니다.
# 51.91% 확률로 긍정^^ 리뷰입니다.
# 92.46% 확률로 부정!! 리뷰입니다.
# 83.29% 확률로 부정!! 리뷰입니다.
# 99.07% 확률로 긍정^^ 리뷰입니다.
# 93.43% 확률로 부정!! 리뷰입니다.
# 96.42% 확률로 긍정^^ 리뷰입니다.
# 62.50% 확률로 긍정^^ 리뷰입니다.
# 54.80% 확률로 부정!! 리뷰입니다.
# 59.02% 확률로 긍정^^ 리뷰입니다.
# 75.47% 확률로 부정!! 리뷰입니다.
# 93.67% 확률로 부정!! 리뷰입니다.
# 82.37% 확률로 부정!! 리뷰입니다.
# 81.88% 확률로 부정!! 리뷰입니다.
# 80.31% 확률로 부정!! 리뷰입니다.
# 93.73% 확률로 부정!! 리뷰입니다.
# 84.05% 확률로 부정!! 리뷰입니다.
# 94.44% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 99.48% 확률로 부정!! 리뷰입니다.
# 77.19% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 97.87% 확률로 부정!! 리뷰입니다.
# 83.86% 확률로 부정!! 리뷰입니다.
# 93.13% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 56.03% 확률로 긍정^^ 리뷰입니다.
# 51.68% 확률로 부정!! 리뷰입니다.
# 82.63% 확률로 부정!! 리뷰입니다.
# 99.07% 확률로 부정!! 리뷰입니다.
# 96.90% 확률로 부정!! 리뷰입니다.
# 57.78% 확률로 긍정^^ 리뷰입니다.
# 71.98% 확률로 부정!! 리뷰입니다.
# 92.11% 확률로 긍정^^ 리뷰입니다.
# 62.09% 확률로 부정!! 리뷰입니다.
# 86.98% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 98.65% 확률로 부정!! 리뷰입니다.
# 92.12% 확률로 부정!! 리뷰입니다.
# 51.30% 확률로 부정!! 리뷰입니다.
# 93.17% 확률로 부정!! 리뷰입니다.
# 69.05% 확률로 부정!! 리뷰입니다.
# 93.62% 확률로 부정!! 리뷰입니다.
# 92.56% 확률로 부정!! 리뷰입니다.
# 80.06% 확률로 긍정^^ 리뷰입니다.
# 84.37% 확률로 부정!! 리뷰입니다.
# 72.60% 확률로 부정!! 리뷰입니다.
# 98.30% 확률로 부정!! 리뷰입니다.
# 57.68% 확률로 부정!! 리뷰입니다.
# 82.24% 확률로 긍정^^ 리뷰입니다.
# 71.95% 확률로 부정!! 리뷰입니다.
# 65.05% 확률로 부정!! 리뷰입니다.
# 66.22% 확률로 부정!! 리뷰입니다.
# 90.41% 확률로 부정!! 리뷰입니다.
# 93.11% 확률로 부정!! 리뷰입니다.
# 90.00% 확률로 긍정^^ 리뷰입니다.
# 70.48% 확률로 부정!! 리뷰입니다.
# 58.07% 확률로 부정!! 리뷰입니다.
# 99.66% 확률로 부정!! 리뷰입니다.
# 99.19% 확률로 부정!! 리뷰입니다.
# 93.84% 확률로 부정!! 리뷰입니다.
# 50.77% 확률로 긍정^^ 리뷰입니다.
# 84.03% 확률로 부정!! 리뷰입니다.
# 91.31% 확률로 부정!! 리뷰입니다.
# 57.20% 확률로 긍정^^ 리뷰입니다.
# 67.69% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 83.21% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 50.07% 확률로 긍정^^ 리뷰입니다.
# 54.82% 확률로 긍정^^ 리뷰입니다.
# 93.48% 확률로 부정!! 리뷰입니다.
# 87.89% 확률로 긍정^^ 리뷰입니다.
# 98.41% 확률로 부정!! 리뷰입니다.
# 96.33% 확률로 긍정^^ 리뷰입니다.
# 86.72% 확률로 부정!! 리뷰입니다.
# 64.51% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 65.68% 확률로 긍정^^ 리뷰입니다.
# 76.72% 확률로 긍정^^ 리뷰입니다.
# 83.20% 확률로 부정!! 리뷰입니다.
# 66.69% 확률로 긍정^^ 리뷰입니다.
# 90.09% 확률로 긍정^^ 리뷰입니다.
# 95.22% 확률로 부정!! 리뷰입니다.
# 78.69% 확률로 부정!! 리뷰입니다.
# 61.74% 확률로 긍정^^ 리뷰입니다.
# 87.85% 확률로 부정!! 리뷰입니다.
# 95.95% 확률로 부정!! 리뷰입니다.
# 92.97% 확률로 부정!! 리뷰입니다.
# 95.30% 확률로 긍정^^ 리뷰입니다.
# 91.72% 확률로 긍정^^ 리뷰입니다.
# 87.78% 확률로 부정!! 리뷰입니다.
# 95.28% 확률로 긍정^^ 리뷰입니다.
# 71.99% 확률로 부정!! 리뷰입니다.
# 96.84% 확률로 부정!! 리뷰입니다.
# 88.14% 확률로 부정!! 리뷰입니다.
# 94.00% 확률로 부정!! 리뷰입니다.
# 91.13% 확률로 부정!! 리뷰입니다.
# 58.18% 확률로 긍정^^ 리뷰입니다.
# 67.79% 확률로 부정!! 리뷰입니다.
# 78.33% 확률로 긍정^^ 리뷰입니다.
# 97.44% 확률로 부정!! 리뷰입니다.
# 96.25% 확률로 부정!! 리뷰입니다.
# 71.96% 확률로 긍정^^ 리뷰입니다.
# 83.45% 확률로 긍정^^ 리뷰입니다.
# 65.86% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 56.59% 확률로 긍정^^ 리뷰입니다.
# 87.52% 확률로 부정!! 리뷰입니다.
# 93.27% 확률로 부정!! 리뷰입니다.
# 96.93% 확률로 부정!! 리뷰입니다.
# 82.34% 확률로 부정!! 리뷰입니다.
# 55.35% 확률로 부정!! 리뷰입니다.
# 90.65% 확률로 부정!! 리뷰입니다.
# 64.86% 확률로 부정!! 리뷰입니다.
# 74.78% 확률로 부정!! 리뷰입니다.
# 96.35% 확률로 부정!! 리뷰입니다.
# 73.42% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 95.62% 확률로 부정!! 리뷰입니다.
# 99.04% 확률로 부정!! 리뷰입니다.
# 77.43% 확률로 부정!! 리뷰입니다.
# 61.10% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.60% 확률로 부정!! 리뷰입니다.
# 89.04% 확률로 긍정^^ 리뷰입니다.
# 96.91% 확률로 긍정^^ 리뷰입니다.
# 78.81% 확률로 부정!! 리뷰입니다.
# 98.62% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 98.46% 확률로 부정!! 리뷰입니다.
# 66.31% 확률로 부정!! 리뷰입니다.
# 90.26% 확률로 부정!! 리뷰입니다.
# 81.81% 확률로 부정!! 리뷰입니다.
# 98.08% 확률로 부정!! 리뷰입니다.
# 84.02% 확률로 부정!! 리뷰입니다.
# 60.42% 확률로 부정!! 리뷰입니다.
# 55.35% 확률로 부정!! 리뷰입니다.
# 55.79% 확률로 부정!! 리뷰입니다.
# 98.01% 확률로 부정!! 리뷰입니다.
# 98.85% 확률로 부정!! 리뷰입니다.
# 70.40% 확률로 부정!! 리뷰입니다.
# 76.56% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 96.56% 확률로 긍정^^ 리뷰입니다.
# 71.09% 확률로 부정!! 리뷰입니다.
# 94.25% 확률로 부정!! 리뷰입니다.
# 67.31% 확률로 부정!! 리뷰입니다.
# 96.23% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 94.58% 확률로 긍정^^ 리뷰입니다.
# 59.56% 확률로 부정!! 리뷰입니다.
# 82.01% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.84% 확률로 부정!! 리뷰입니다.
# 89.85% 확률로 부정!! 리뷰입니다.
# 95.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 87.55% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 86.78% 확률로 부정!! 리뷰입니다.
# 59.88% 확률로 부정!! 리뷰입니다.
# 57.76% 확률로 긍정^^ 리뷰입니다.
# 97.54% 확률로 긍정^^ 리뷰입니다.
# 69.22% 확률로 긍정^^ 리뷰입니다.
# 99.29% 확률로 부정!! 리뷰입니다.
# 80.61% 확률로 부정!! 리뷰입니다.
# 98.83% 확률로 부정!! 리뷰입니다.
# 75.05% 확률로 부정!! 리뷰입니다.
# 97.36% 확률로 부정!! 리뷰입니다.
# 91.42% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 92.25% 확률로 부정!! 리뷰입니다.
# 76.45% 확률로 부정!! 리뷰입니다.
# 68.94% 확률로 긍정^^ 리뷰입니다.
# 52.75% 확률로 긍정^^ 리뷰입니다.
# 70.92% 확률로 긍정^^ 리뷰입니다.
# 84.01% 확률로 긍정^^ 리뷰입니다.
# 55.79% 확률로 부정!! 리뷰입니다.
# 82.43% 확률로 부정!! 리뷰입니다.
# 95.99% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 93.85% 확률로 부정!! 리뷰입니다.
# 73.03% 확률로 부정!! 리뷰입니다.
# 84.15% 확률로 부정!! 리뷰입니다.
# 87.03% 확률로 부정!! 리뷰입니다.
# 86.85% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 63.54% 확률로 긍정^^ 리뷰입니다.
# 65.86% 확률로 부정!! 리뷰입니다.
# 59.88% 확률로 부정!! 리뷰입니다.
# 97.41% 확률로 부정!! 리뷰입니다.
# 53.23% 확률로 긍정^^ 리뷰입니다.
# 84.68% 확률로 부정!! 리뷰입니다.
# 70.63% 확률로 부정!! 리뷰입니다.
# 90.32% 확률로 부정!! 리뷰입니다.
# 93.91% 확률로 부정!! 리뷰입니다.
# 98.77% 확률로 부정!! 리뷰입니다.
# 90.76% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 67.12% 확률로 부정!! 리뷰입니다.
# 77.56% 확률로 부정!! 리뷰입니다.
# 98.66% 확률로 긍정^^ 리뷰입니다.
# 97.27% 확률로 부정!! 리뷰입니다.
# 63.73% 확률로 부정!! 리뷰입니다.
# 80.33% 확률로 부정!! 리뷰입니다.
# 70.19% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 80.87% 확률로 부정!! 리뷰입니다.
# 85.64% 확률로 긍정^^ 리뷰입니다.
# 77.22% 확률로 부정!! 리뷰입니다.
# 56.71% 확률로 부정!! 리뷰입니다.
# 95.17% 확률로 부정!! 리뷰입니다.
# 77.76% 확률로 부정!! 리뷰입니다.
# 66.25% 확률로 긍정^^ 리뷰입니다.
# 98.02% 확률로 부정!! 리뷰입니다.
# 69.48% 확률로 부정!! 리뷰입니다.
# 94.77% 확률로 긍정^^ 리뷰입니다.
# 88.72% 확률로 부정!! 리뷰입니다.
# 65.44% 확률로 부정!! 리뷰입니다.
# 56.02% 확률로 부정!! 리뷰입니다.
# 74.60% 확률로 긍정^^ 리뷰입니다.
# 83.38% 확률로 부정!! 리뷰입니다.
# 66.91% 확률로 긍정^^ 리뷰입니다.
# 63.48% 확률로 긍정^^ 리뷰입니다.
# 60.08% 확률로 긍정^^ 리뷰입니다.
# 55.12% 확률로 긍정^^ 리뷰입니다.
# 53.03% 확률로 부정!! 리뷰입니다.
# 96.61% 확률로 부정!! 리뷰입니다.
# 76.10% 확률로 긍정^^ 리뷰입니다.
# 73.86% 확률로 부정!! 리뷰입니다.
# 91.41% 확률로 긍정^^ 리뷰입니다.
# 96.99% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 58.98% 확률로 부정!! 리뷰입니다.
# 55.35% 확률로 부정!! 리뷰입니다.
# 73.86% 확률로 부정!! 리뷰입니다.
# 85.41% 확률로 부정!! 리뷰입니다.
# 78.76% 확률로 부정!! 리뷰입니다.
# 60.24% 확률로 부정!! 리뷰입니다.
# 83.38% 확률로 부정!! 리뷰입니다.
# 62.99% 확률로 부정!! 리뷰입니다.
# 77.01% 확률로 부정!! 리뷰입니다.
# 98.14% 확률로 부정!! 리뷰입니다.
# 83.19% 확률로 부정!! 리뷰입니다.
# 93.33% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 50.49% 확률로 긍정^^ 리뷰입니다.
# 94.17% 확률로 부정!! 리뷰입니다.
# 77.01% 확률로 부정!! 리뷰입니다.
# 95.84% 확률로 부정!! 리뷰입니다.
# 83.54% 확률로 부정!! 리뷰입니다.
# 53.33% 확률로 긍정^^ 리뷰입니다.
# 68.51% 확률로 부정!! 리뷰입니다.
# 56.64% 확률로 긍정^^ 리뷰입니다.
# 66.98% 확률로 긍정^^ 리뷰입니다.
# 55.94% 확률로 부정!! 리뷰입니다.
# 96.15% 확률로 부정!! 리뷰입니다.
# 65.58% 확률로 긍정^^ 리뷰입니다.
# 59.27% 확률로 부정!! 리뷰입니다.
# 84.94% 확률로 부정!! 리뷰입니다.
# 65.86% 확률로 부정!! 리뷰입니다.
# 87.77% 확률로 부정!! 리뷰입니다.
# 80.62% 확률로 부정!! 리뷰입니다.
# 67.53% 확률로 부정!! 리뷰입니다.
# 81.59% 확률로 부정!! 리뷰입니다.
# 53.54% 확률로 부정!! 리뷰입니다.
# 80.32% 확률로 부정!! 리뷰입니다.
# 61.77% 확률로 긍정^^ 리뷰입니다.
# 95.23% 확률로 부정!! 리뷰입니다.
# 96.83% 확률로 부정!! 리뷰입니다.
# 53.20% 확률로 부정!! 리뷰입니다.
# 99.42% 확률로 부정!! 리뷰입니다.
# 52.84% 확률로 긍정^^ 리뷰입니다.
# 52.84% 확률로 긍정^^ 리뷰입니다.
# 50.57% 확률로 긍정^^ 리뷰입니다.
# 86.63% 확률로 긍정^^ 리뷰입니다.
# 72.12% 확률로 긍정^^ 리뷰입니다.
# 55.35% 확률로 부정!! 리뷰입니다.
# 53.93% 확률로 부정!! 리뷰입니다.
# 62.10% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 80.86% 확률로 긍정^^ 리뷰입니다.
# 88.74% 확률로 부정!! 리뷰입니다.
# 71.13% 확률로 긍정^^ 리뷰입니다.
# 60.26% 확률로 부정!! 리뷰입니다.
# 97.70% 확률로 부정!! 리뷰입니다.
# 97.68% 확률로 부정!! 리뷰입니다.
# 79.11% 확률로 부정!! 리뷰입니다.
# 69.78% 확률로 부정!! 리뷰입니다.
# 96.83% 확률로 부정!! 리뷰입니다.
# 70.63% 확률로 부정!! 리뷰입니다.
# 62.14% 확률로 부정!! 리뷰입니다.
# 74.08% 확률로 부정!! 리뷰입니다.
# 81.20% 확률로 부정!! 리뷰입니다.
# 86.33% 확률로 부정!! 리뷰입니다.
# 83.78% 확률로 부정!! 리뷰입니다.
# 64.22% 확률로 부정!! 리뷰입니다.
# 67.17% 확률로 긍정^^ 리뷰입니다.
# 92.18% 확률로 부정!! 리뷰입니다.
# 79.22% 확률로 부정!! 리뷰입니다.
# 61.61% 확률로 부정!! 리뷰입니다.
# 97.03% 확률로 부정!! 리뷰입니다.
# 73.37% 확률로 부정!! 리뷰입니다.
# 84.29% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 55.03% 확률로 긍정^^ 리뷰입니다.
# 92.83% 확률로 부정!! 리뷰입니다.
# 88.30% 확률로 부정!! 리뷰입니다.
# 57.02% 확률로 부정!! 리뷰입니다.
# 86.59% 확률로 부정!! 리뷰입니다.
# 91.00% 확률로 부정!! 리뷰입니다.
# 88.45% 확률로 부정!! 리뷰입니다.
# 78.65% 확률로 부정!! 리뷰입니다.
# 96.16% 확률로 부정!! 리뷰입니다.
# 59.02% 확률로 부정!! 리뷰입니다.
# 91.03% 확률로 부정!! 리뷰입니다.
# 91.99% 확률로 부정!! 리뷰입니다.
# 67.48% 확률로 긍정^^ 리뷰입니다.
# 99.78% 확률로 부정!! 리뷰입니다.
# 97.62% 확률로 부정!! 리뷰입니다.
# 57.60% 확률로 부정!! 리뷰입니다.
# 80.60% 확률로 부정!! 리뷰입니다.
# 69.28% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 99.31% 확률로 부정!! 리뷰입니다.
# 85.62% 확률로 부정!! 리뷰입니다.
# 92.56% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.85% 확률로 부정!! 리뷰입니다.
# 98.19% 확률로 긍정^^ 리뷰입니다.
# 65.98% 확률로 부정!! 리뷰입니다.
# 67.56% 확률로 긍정^^ 리뷰입니다.
# 64.74% 확률로 부정!! 리뷰입니다.
# 82.79% 확률로 긍정^^ 리뷰입니다.
# 77.35% 확률로 부정!! 리뷰입니다.
# 80.98% 확률로 부정!! 리뷰입니다.
# 93.61% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 90.73% 확률로 부정!! 리뷰입니다.
# 82.04% 확률로 부정!! 리뷰입니다.
# 58.53% 확률로 긍정^^ 리뷰입니다.
# 61.77% 확률로 긍정^^ 리뷰입니다.
# 55.31% 확률로 긍정^^ 리뷰입니다.
# 59.16% 확률로 부정!! 리뷰입니다.
# 92.14% 확률로 부정!! 리뷰입니다.
# 57.90% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 65.68% 확률로 긍정^^ 리뷰입니다.
# 92.06% 확률로 부정!! 리뷰입니다.
# 98.26% 확률로 부정!! 리뷰입니다.
# 68.64% 확률로 부정!! 리뷰입니다.
# 82.50% 확률로 부정!! 리뷰입니다.
# 87.51% 확률로 긍정^^ 리뷰입니다.
# 59.38% 확률로 긍정^^ 리뷰입니다.
# 70.63% 확률로 부정!! 리뷰입니다.
# 90.44% 확률로 긍정^^ 리뷰입니다.
# 59.13% 확률로 긍정^^ 리뷰입니다.
# 96.83% 확률로 긍정^^ 리뷰입니다.
# 73.27% 확률로 긍정^^ 리뷰입니다.
# 73.50% 확률로 부정!! 리뷰입니다.
# 83.98% 확률로 부정!! 리뷰입니다.
# 58.89% 확률로 부정!! 리뷰입니다.
# 64.00% 확률로 부정!! 리뷰입니다.
# 92.68% 확률로 긍정^^ 리뷰입니다.
# 82.53% 확률로 긍정^^ 리뷰입니다.
# 58.97% 확률로 부정!! 리뷰입니다.
# 88.75% 확률로 긍정^^ 리뷰입니다.
# 59.48% 확률로 긍정^^ 리뷰입니다.
# 92.56% 확률로 긍정^^ 리뷰입니다.
# 95.31% 확률로 긍정^^ 리뷰입니다.
# 53.29% 확률로 긍정^^ 리뷰입니다.
# 94.60% 확률로 긍정^^ 리뷰입니다.
# 61.24% 확률로 부정!! 리뷰입니다.
# 98.17% 확률로 부정!! 리뷰입니다.
# 86.99% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 62.24% 확률로 부정!! 리뷰입니다.
# 85.35% 확률로 부정!! 리뷰입니다.
# 87.39% 확률로 부정!! 리뷰입니다.
# 89.60% 확률로 부정!! 리뷰입니다.
# 77.41% 확률로 부정!! 리뷰입니다.
# 76.19% 확률로 부정!! 리뷰입니다.
# 63.85% 확률로 부정!! 리뷰입니다.
# 85.85% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 80.37% 확률로 긍정^^ 리뷰입니다.
# 62.53% 확률로 부정!! 리뷰입니다.
# 92.07% 확률로 긍정^^ 리뷰입니다.
# 60.98% 확률로 긍정^^ 리뷰입니다.
# 91.25% 확률로 부정!! 리뷰입니다.
# 55.68% 확률로 부정!! 리뷰입니다.
# 70.77% 확률로 부정!! 리뷰입니다.
# 60.73% 확률로 부정!! 리뷰입니다.
# 89.75% 확률로 부정!! 리뷰입니다.
# 96.79% 확률로 부정!! 리뷰입니다.
# 51.30% 확률로 긍정^^ 리뷰입니다.
# 89.14% 확률로 부정!! 리뷰입니다.
# 72.17% 확률로 부정!! 리뷰입니다.
# 65.92% 확률로 부정!! 리뷰입니다.
# 57.19% 확률로 부정!! 리뷰입니다.
# 83.18% 확률로 부정!! 리뷰입니다.
# 70.06% 확률로 부정!! 리뷰입니다.
# 68.40% 확률로 부정!! 리뷰입니다.
# 59.42% 확률로 부정!! 리뷰입니다.
# 64.57% 확률로 긍정^^ 리뷰입니다.
# 92.64% 확률로 부정!! 리뷰입니다.
# 74.88% 확률로 긍정^^ 리뷰입니다.
# 72.33% 확률로 부정!! 리뷰입니다.
# 77.52% 확률로 긍정^^ 리뷰입니다.
# 91.84% 확률로 긍정^^ 리뷰입니다.
# 75.66% 확률로 긍정^^ 리뷰입니다.
# 98.25% 확률로 긍정^^ 리뷰입니다.
# 82.64% 확률로 부정!! 리뷰입니다.
# 93.93% 확률로 긍정^^ 리뷰입니다.
# 74.10% 확률로 부정!! 리뷰입니다.
# 98.13% 확률로 부정!! 리뷰입니다.
# 85.84% 확률로 긍정^^ 리뷰입니다.
# 72.59% 확률로 부정!! 리뷰입니다.
# 77.34% 확률로 긍정^^ 리뷰입니다.
# 60.42% 확률로 부정!! 리뷰입니다.
# 79.37% 확률로 긍정^^ 리뷰입니다.
# 50.97% 확률로 부정!! 리뷰입니다.
# 78.74% 확률로 긍정^^ 리뷰입니다.
# 88.51% 확률로 긍정^^ 리뷰입니다.
# 66.45% 확률로 긍정^^ 리뷰입니다.
# 93.50% 확률로 긍정^^ 리뷰입니다.
# 91.62% 확률로 긍정^^ 리뷰입니다.
# 70.18% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 56.40% 확률로 긍정^^ 리뷰입니다.
# 79.22% 확률로 긍정^^ 리뷰입니다.
# 78.12% 확률로 부정!! 리뷰입니다.
# 95.28% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 63.73% 확률로 부정!! 리뷰입니다.
# 97.18% 확률로 부정!! 리뷰입니다.
# 83.48% 확률로 부정!! 리뷰입니다.
# 65.97% 확률로 부정!! 리뷰입니다.
# 58.53% 확률로 부정!! 리뷰입니다.
# 71.27% 확률로 부정!! 리뷰입니다.
# 70.75% 확률로 긍정^^ 리뷰입니다.
# 67.69% 확률로 부정!! 리뷰입니다.
# 79.07% 확률로 부정!! 리뷰입니다.
# 69.68% 확률로 부정!! 리뷰입니다.
# 85.21% 확률로 부정!! 리뷰입니다.
# 72.98% 확률로 부정!! 리뷰입니다.
# 83.48% 확률로 부정!! 리뷰입니다.
# 72.84% 확률로 긍정^^ 리뷰입니다.
# 66.95% 확률로 긍정^^ 리뷰입니다.
# 53.44% 확률로 부정!! 리뷰입니다.
# 50.65% 확률로 긍정^^ 리뷰입니다.
# 70.73% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 74.32% 확률로 긍정^^ 리뷰입니다.
# 78.08% 확률로 긍정^^ 리뷰입니다.
# 65.31% 확률로 부정!! 리뷰입니다.
# 83.67% 확률로 긍정^^ 리뷰입니다.
# 53.51% 확률로 긍정^^ 리뷰입니다.
# 73.51% 확률로 긍정^^ 리뷰입니다.
# 50.01% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 81.38% 확률로 부정!! 리뷰입니다.
# 55.10% 확률로 긍정^^ 리뷰입니다.
# 85.48% 확률로 긍정^^ 리뷰입니다.
# 50.77% 확률로 부정!! 리뷰입니다.
# 72.10% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 53.19% 확률로 부정!! 리뷰입니다.
# 54.86% 확률로 부정!! 리뷰입니다.
# 59.57% 확률로 긍정^^ 리뷰입니다.
# 54.50% 확률로 부정!! 리뷰입니다.
# 87.15% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 55.35% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 80.64% 확률로 긍정^^ 리뷰입니다.
# 69.21% 확률로 긍정^^ 리뷰입니다.
# 64.51% 확률로 긍정^^ 리뷰입니다.
# 95.89% 확률로 긍정^^ 리뷰입니다.
# 58.63% 확률로 부정!! 리뷰입니다.
# 89.45% 확률로 긍정^^ 리뷰입니다.
# 99.10% 확률로 부정!! 리뷰입니다.
# 87.52% 확률로 긍정^^ 리뷰입니다.
# 50.18% 확률로 긍정^^ 리뷰입니다.
# 87.67% 확률로 부정!! 리뷰입니다.
# 55.53% 확률로 긍정^^ 리뷰입니다.
# 59.55% 확률로 긍정^^ 리뷰입니다.
# 68.99% 확률로 부정!! 리뷰입니다.
# 56.13% 확률로 긍정^^ 리뷰입니다.
# 95.31% 확률로 부정!! 리뷰입니다.
# 98.48% 확률로 부정!! 리뷰입니다.
# 80.41% 확률로 긍정^^ 리뷰입니다.
# 59.29% 확률로 긍정^^ 리뷰입니다.
# 62.75% 확률로 긍정^^ 리뷰입니다.
# 52.30% 확률로 부정!! 리뷰입니다.
# 90.65% 확률로 긍정^^ 리뷰입니다.
# 72.96% 확률로 긍정^^ 리뷰입니다.
# 82.24% 확률로 긍정^^ 리뷰입니다.
# 63.39% 확률로 부정!! 리뷰입니다.
# 52.82% 확률로 부정!! 리뷰입니다.
# 97.74% 확률로 부정!! 리뷰입니다.
# 69.18% 확률로 긍정^^ 리뷰입니다.
# 85.16% 확률로 긍정^^ 리뷰입니다.
# 71.89% 확률로 부정!! 리뷰입니다.
# 77.87% 확률로 부정!! 리뷰입니다.
# 60.26% 확률로 부정!! 리뷰입니다.
# 67.47% 확률로 긍정^^ 리뷰입니다.
# 71.32% 확률로 긍정^^ 리뷰입니다.
# 62.95% 확률로 긍정^^ 리뷰입니다.
# 90.90% 확률로 부정!! 리뷰입니다.
# 80.07% 확률로 부정!! 리뷰입니다.
# 63.20% 확률로 긍정^^ 리뷰입니다.
# 78.68% 확률로 부정!! 리뷰입니다.
# 80.37% 확률로 부정!! 리뷰입니다.
# 58.18% 확률로 부정!! 리뷰입니다.
# 60.51% 확률로 긍정^^ 리뷰입니다.
# 85.92% 확률로 긍정^^ 리뷰입니다.
# 74.50% 확률로 긍정^^ 리뷰입니다.
# 60.43% 확률로 부정!! 리뷰입니다.
# 75.74% 확률로 긍정^^ 리뷰입니다.
# 83.34% 확률로 긍정^^ 리뷰입니다.
# 90.46% 확률로 긍정^^ 리뷰입니다.
# 80.66% 확률로 긍정^^ 리뷰입니다.
# 50.36% 확률로 부정!! 리뷰입니다.
# 66.92% 확률로 부정!! 리뷰입니다.
# 99.57% 확률로 부정!! 리뷰입니다.
# 89.71% 확률로 부정!! 리뷰입니다.
# 89.71% 확률로 부정!! 리뷰입니다.
# 89.71% 확률로 부정!! 리뷰입니다.
# 84.35% 확률로 부정!! 리뷰입니다.
# 79.75% 확률로 긍정^^ 리뷰입니다.
# 81.19% 확률로 부정!! 리뷰입니다.
# 71.35% 확률로 부정!! 리뷰입니다.
# 52.76% 확률로 긍정^^ 리뷰입니다.
# 55.95% 확률로 긍정^^ 리뷰입니다.
# 55.95% 확률로 긍정^^ 리뷰입니다.
# 58.89% 확률로 긍정^^ 리뷰입니다.
# 57.90% 확률로 긍정^^ 리뷰입니다.
# 82.78% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 88.73% 확률로 긍정^^ 리뷰입니다.
# 78.23% 확률로 긍정^^ 리뷰입니다.
# 70.63% 확률로 부정!! 리뷰입니다.
# 83.58% 확률로 긍정^^ 리뷰입니다.
# 67.86% 확률로 부정!! 리뷰입니다.
# 89.06% 확률로 긍정^^ 리뷰입니다.
# 64.30% 확률로 긍정^^ 리뷰입니다.
# 67.04% 확률로 긍정^^ 리뷰입니다.
# 90.13% 확률로 긍정^^ 리뷰입니다.
# 93.57% 확률로 긍정^^ 리뷰입니다.
# 82.15% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 56.57% 확률로 긍정^^ 리뷰입니다.
# 53.45% 확률로 긍정^^ 리뷰입니다.
# 62.10% 확률로 부정!! 리뷰입니다.
# 93.57% 확률로 부정!! 리뷰입니다.
# 61.77% 확률로 긍정^^ 리뷰입니다.
# 75.21% 확률로 부정!! 리뷰입니다.
# 91.08% 확률로 부정!! 리뷰입니다.
# 73.75% 확률로 부정!! 리뷰입니다.
# 62.90% 확률로 부정!! 리뷰입니다.
# 51.48% 확률로 부정!! 리뷰입니다.
# 69.62% 확률로 긍정^^ 리뷰입니다.
# 50.89% 확률로 긍정^^ 리뷰입니다.
# 81.48% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 65.37% 확률로 긍정^^ 리뷰입니다.
# 57.60% 확률로 긍정^^ 리뷰입니다.
# 90.06% 확률로 긍정^^ 리뷰입니다.
# 64.42% 확률로 부정!! 리뷰입니다.
# 78.97% 확률로 부정!! 리뷰입니다.
# 60.56% 확률로 긍정^^ 리뷰입니다.
# 55.54% 확률로 부정!! 리뷰입니다.
# 57.24% 확률로 부정!! 리뷰입니다.
# 52.46% 확률로 긍정^^ 리뷰입니다.
# 98.69% 확률로 부정!! 리뷰입니다.
# 60.59% 확률로 긍정^^ 리뷰입니다.
# 94.09% 확률로 부정!! 리뷰입니다.
# 65.75% 확률로 부정!! 리뷰입니다.
# 79.65% 확률로 긍정^^ 리뷰입니다.
# 91.58% 확률로 부정!! 리뷰입니다.
# 52.57% 확률로 긍정^^ 리뷰입니다.
# 56.44% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 79.85% 확률로 부정!! 리뷰입니다.
# 55.79% 확률로 부정!! 리뷰입니다.
# 72.65% 확률로 부정!! 리뷰입니다.
# 62.18% 확률로 부정!! 리뷰입니다.
# 65.48% 확률로 부정!! 리뷰입니다.
# 85.46% 확률로 부정!! 리뷰입니다.
# 83.78% 확률로 긍정^^ 리뷰입니다.
# 86.04% 확률로 긍정^^ 리뷰입니다.
# 93.27% 확률로 부정!! 리뷰입니다.
# 65.74% 확률로 긍정^^ 리뷰입니다.
# 96.85% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 70.87% 확률로 부정!! 리뷰입니다.
# 89.41% 확률로 부정!! 리뷰입니다.
# 77.58% 확률로 부정!! 리뷰입니다.
# 97.00% 확률로 긍정^^ 리뷰입니다.
# 82.43% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 53.47% 확률로 긍정^^ 리뷰입니다.
# 85.35% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 80.62% 확률로 부정!! 리뷰입니다.
# 86.26% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 87.70% 확률로 부정!! 리뷰입니다.
# 61.02% 확률로 부정!! 리뷰입니다.
# 50.68% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 99.46% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 94.83% 확률로 부정!! 리뷰입니다.
# 99.20% 확률로 부정!! 리뷰입니다.
# 99.59% 확률로 부정!! 리뷰입니다.
# 80.18% 확률로 부정!! 리뷰입니다.
# 66.57% 확률로 부정!! 리뷰입니다.
# 74.31% 확률로 부정!! 리뷰입니다.
# 53.95% 확률로 긍정^^ 리뷰입니다.
# 99.17% 확률로 부정!! 리뷰입니다.
# 99.39% 확률로 부정!! 리뷰입니다.
# 92.11% 확률로 부정!! 리뷰입니다.
# 87.40% 확률로 부정!! 리뷰입니다.
# 93.18% 확률로 부정!! 리뷰입니다.
# 50.68% 확률로 긍정^^ 리뷰입니다.
# 79.13% 확률로 긍정^^ 리뷰입니다.
# 77.83% 확률로 긍정^^ 리뷰입니다.
# 65.86% 확률로 부정!! 리뷰입니다.
# 90.22% 확률로 부정!! 리뷰입니다.
# 98.24% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 65.48% 확률로 부정!! 리뷰입니다.
# 95.97% 확률로 부정!! 리뷰입니다.
# 89.28% 확률로 부정!! 리뷰입니다.
# 83.80% 확률로 부정!! 리뷰입니다.
# 99.24% 확률로 부정!! 리뷰입니다.
# 95.66% 확률로 긍정^^ 리뷰입니다.
# 91.11% 확률로 부정!! 리뷰입니다.
# 89.55% 확률로 긍정^^ 리뷰입니다.
# 62.88% 확률로 긍정^^ 리뷰입니다.
# 92.60% 확률로 부정!! 리뷰입니다.
# 72.25% 확률로 부정!! 리뷰입니다.
# 83.83% 확률로 부정!! 리뷰입니다.
# 59.80% 확률로 부정!! 리뷰입니다.
# 55.00% 확률로 부정!! 리뷰입니다.
# 81.77% 확률로 부정!! 리뷰입니다.
# 59.43% 확률로 긍정^^ 리뷰입니다.
# 94.41% 확률로 긍정^^ 리뷰입니다.
# 89.83% 확률로 부정!! 리뷰입니다.
# 96.38% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 79.11% 확률로 부정!! 리뷰입니다.
# 93.22% 확률로 긍정^^ 리뷰입니다.
# 99.19% 확률로 부정!! 리뷰입니다.
# 98.89% 확률로 부정!! 리뷰입니다.
# 58.52% 확률로 부정!! 리뷰입니다.
# 97.13% 확률로 부정!! 리뷰입니다.
# 90.40% 확률로 부정!! 리뷰입니다.
# 77.14% 확률로 긍정^^ 리뷰입니다.
# 79.50% 확률로 긍정^^ 리뷰입니다.
# 97.46% 확률로 긍정^^ 리뷰입니다.
# 91.06% 확률로 부정!! 리뷰입니다.
# 89.27% 확률로 부정!! 리뷰입니다.
# 90.31% 확률로 부정!! 리뷰입니다.
# 82.74% 확률로 긍정^^ 리뷰입니다.
# 85.94% 확률로 부정!! 리뷰입니다.
# 91.07% 확률로 긍정^^ 리뷰입니다.
# 67.46% 확률로 긍정^^ 리뷰입니다.
# 91.13% 확률로 부정!! 리뷰입니다.
# 72.04% 확률로 부정!! 리뷰입니다.
# 50.79% 확률로 긍정^^ 리뷰입니다.
# 89.25% 확률로 부정!! 리뷰입니다.
# 58.97% 확률로 부정!! 리뷰입니다.
# 98.85% 확률로 부정!! 리뷰입니다.
# 69.20% 확률로 부정!! 리뷰입니다.
# 99.06% 확률로 부정!! 리뷰입니다.
# 80.99% 확률로 부정!! 리뷰입니다.
# 71.58% 확률로 긍정^^ 리뷰입니다.
# 97.28% 확률로 부정!! 리뷰입니다.
# 94.57% 확률로 부정!! 리뷰입니다.
# 96.42% 확률로 긍정^^ 리뷰입니다.
# 92.50% 확률로 부정!! 리뷰입니다.
# 86.01% 확률로 부정!! 리뷰입니다.
# 89.73% 확률로 부정!! 리뷰입니다.
# 68.97% 확률로 부정!! 리뷰입니다.
# 98.53% 확률로 긍정^^ 리뷰입니다.
# 67.46% 확률로 긍정^^ 리뷰입니다.
# 96.53% 확률로 긍정^^ 리뷰입니다.
# 52.68% 확률로 긍정^^ 리뷰입니다.
# 78.26% 확률로 긍정^^ 리뷰입니다.
# 95.23% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 77.88% 확률로 부정!! 리뷰입니다.
# 83.59% 확률로 부정!! 리뷰입니다.
# 98.06% 확률로 부정!! 리뷰입니다.
# 91.75% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 81.31% 확률로 부정!! 리뷰입니다.
# 70.79% 확률로 긍정^^ 리뷰입니다.
# 80.66% 확률로 긍정^^ 리뷰입니다.
# 80.66% 확률로 긍정^^ 리뷰입니다.
# 80.66% 확률로 긍정^^ 리뷰입니다.
# 80.66% 확률로 긍정^^ 리뷰입니다.
# 94.98% 확률로 부정!! 리뷰입니다.
# 99.76% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 71.54% 확률로 긍정^^ 리뷰입니다.
# 77.98% 확률로 부정!! 리뷰입니다.
# 80.66% 확률로 긍정^^ 리뷰입니다.
# 70.63% 확률로 부정!! 리뷰입니다.
# 99.70% 확률로 긍정^^ 리뷰입니다.
# 99.07% 확률로 부정!! 리뷰입니다.
# 61.27% 확률로 부정!! 리뷰입니다.
# 97.59% 확률로 부정!! 리뷰입니다.
# 91.71% 확률로 부정!! 리뷰입니다.
# 55.35% 확률로 부정!! 리뷰입니다.
# 60.05% 확률로 긍정^^ 리뷰입니다.
# 69.96% 확률로 긍정^^ 리뷰입니다.
# 96.98% 확률로 긍정^^ 리뷰입니다.
# 85.39% 확률로 부정!! 리뷰입니다.
# 54.72% 확률로 긍정^^ 리뷰입니다.
# 95.60% 확률로 긍정^^ 리뷰입니다.
# 53.40% 확률로 부정!! 리뷰입니다.
# 85.25% 확률로 긍정^^ 리뷰입니다.
# 91.50% 확률로 부정!! 리뷰입니다.
# 96.19% 확률로 부정!! 리뷰입니다.
# 95.88% 확률로 부정!! 리뷰입니다.
# 66.07% 확률로 부정!! 리뷰입니다.
# 77.14% 확률로 긍정^^ 리뷰입니다.
# 55.35% 확률로 부정!! 리뷰입니다.
# 79.75% 확률로 부정!! 리뷰입니다.
# 79.75% 확률로 부정!! 리뷰입니다.
# 78.42% 확률로 부정!! 리뷰입니다.
# 89.38% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 93.53% 확률로 부정!! 리뷰입니다.
# 54.79% 확률로 부정!! 리뷰입니다.
# 91.13% 확률로 부정!! 리뷰입니다.
# 96.87% 확률로 부정!! 리뷰입니다.
# 75.75% 확률로 부정!! 리뷰입니다.
# 53.12% 확률로 긍정^^ 리뷰입니다.
# 96.59% 확률로 긍정^^ 리뷰입니다.
# 76.67% 확률로 부정!! 리뷰입니다.
# 97.17% 확률로 부정!! 리뷰입니다.
# 99.18% 확률로 부정!! 리뷰입니다.
# 86.45% 확률로 부정!! 리뷰입니다.
# 91.09% 확률로 부정!! 리뷰입니다.
# 93.49% 확률로 부정!! 리뷰입니다.
# 72.96% 확률로 부정!! 리뷰입니다.
# 59.69% 확률로 부정!! 리뷰입니다.
# 97.44% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 91.24% 확률로 부정!! 리뷰입니다.
# 84.15% 확률로 부정!! 리뷰입니다.
# 53.37% 확률로 부정!! 리뷰입니다.
# 52.21% 확률로 긍정^^ 리뷰입니다.
# 64.58% 확률로 긍정^^ 리뷰입니다.
# 65.86% 확률로 부정!! 리뷰입니다.
# 87.55% 확률로 부정!! 리뷰입니다.
# 87.12% 확률로 부정!! 리뷰입니다.
# 97.81% 확률로 부정!! 리뷰입니다.
# 86.70% 확률로 부정!! 리뷰입니다.
# 61.46% 확률로 긍정^^ 리뷰입니다.
# 70.21% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 79.70% 확률로 부정!! 리뷰입니다.
# 99.43% 확률로 긍정^^ 리뷰입니다.
# 66.45% 확률로 부정!! 리뷰입니다.
# 95.26% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 60.11% 확률로 긍정^^ 리뷰입니다.
# 60.11% 확률로 긍정^^ 리뷰입니다.
# 84.19% 확률로 긍정^^ 리뷰입니다.
# 74.84% 확률로 긍정^^ 리뷰입니다.
# 85.61% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 89.08% 확률로 부정!! 리뷰입니다.
# 62.29% 확률로 긍정^^ 리뷰입니다.
# 85.91% 확률로 긍정^^ 리뷰입니다.
# 95.27% 확률로 부정!! 리뷰입니다.
# 65.27% 확률로 긍정^^ 리뷰입니다.
# 57.74% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 68.99% 확률로 부정!! 리뷰입니다.
# 80.47% 확률로 부정!! 리뷰입니다.
# 58.45% 확률로 부정!! 리뷰입니다.
# 72.54% 확률로 긍정^^ 리뷰입니다.
# 78.36% 확률로 부정!! 리뷰입니다.
# 84.48% 확률로 긍정^^ 리뷰입니다.
# 84.54% 확률로 부정!! 리뷰입니다.
# 83.42% 확률로 부정!! 리뷰입니다.
# 90.78% 확률로 부정!! 리뷰입니다.
# 52.58% 확률로 긍정^^ 리뷰입니다.
# 91.25% 확률로 부정!! 리뷰입니다.
# 79.79% 확률로 부정!! 리뷰입니다.
# 70.29% 확률로 부정!! 리뷰입니다.
# 76.89% 확률로 긍정^^ 리뷰입니다.
# 91.27% 확률로 긍정^^ 리뷰입니다.
# 85.20% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 99.38% 확률로 긍정^^ 리뷰입니다.
# 66.23% 확률로 부정!! 리뷰입니다.
# 99.38% 확률로 긍정^^ 리뷰입니다.
# 99.38% 확률로 긍정^^ 리뷰입니다.
# 92.57% 확률로 부정!! 리뷰입니다.
# 97.71% 확률로 긍정^^ 리뷰입니다.
# 77.14% 확률로 긍정^^ 리뷰입니다.
# 64.46% 확률로 부정!! 리뷰입니다.
# 58.96% 확률로 부정!! 리뷰입니다.
# 88.41% 확률로 긍정^^ 리뷰입니다.
# 87.67% 확률로 부정!! 리뷰입니다.
# 78.23% 확률로 부정!! 리뷰입니다.
# 60.30% 확률로 부정!! 리뷰입니다.
# 89.91% 확률로 긍정^^ 리뷰입니다.
# 83.80% 확률로 긍정^^ 리뷰입니다.
# 64.73% 확률로 부정!! 리뷰입니다.
# 91.44% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 78.23% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 84.00% 확률로 부정!! 리뷰입니다.
# 89.61% 확률로 부정!! 리뷰입니다.
# 80.41% 확률로 부정!! 리뷰입니다.
# 70.63% 확률로 부정!! 리뷰입니다.
# 87.64% 확률로 부정!! 리뷰입니다.
# 72.19% 확률로 긍정^^ 리뷰입니다.
# 95.33% 확률로 부정!! 리뷰입니다.
# 50.26% 확률로 긍정^^ 리뷰입니다.
# 57.22% 확률로 부정!! 리뷰입니다.
# 76.39% 확률로 부정!! 리뷰입니다.
# 59.80% 확률로 부정!! 리뷰입니다.
# 78.15% 확률로 부정!! 리뷰입니다.
# 91.46% 확률로 부정!! 리뷰입니다.
# 87.64% 확률로 부정!! 리뷰입니다.
# 82.76% 확률로 부정!! 리뷰입니다.
# 65.14% 확률로 부정!! 리뷰입니다.
# 51.07% 확률로 부정!! 리뷰입니다.
# 86.25% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 78.23% 확률로 부정!! 리뷰입니다.
# 99.29% 확률로 부정!! 리뷰입니다.
# 54.51% 확률로 긍정^^ 리뷰입니다.
# 90.48% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 77.18% 확률로 긍정^^ 리뷰입니다.
# 94.94% 확률로 부정!! 리뷰입니다.
# 61.42% 확률로 부정!! 리뷰입니다.
# 60.38% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 83.31% 확률로 부정!! 리뷰입니다.
# 50.77% 확률로 부정!! 리뷰입니다.
# 99.01% 확률로 부정!! 리뷰입니다.
# 83.38% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 69.39% 확률로 긍정^^ 리뷰입니다.
# 99.13% 확률로 부정!! 리뷰입니다.
# 96.46% 확률로 부정!! 리뷰입니다.
# 98.59% 확률로 부정!! 리뷰입니다.
# 51.33% 확률로 긍정^^ 리뷰입니다.
# 78.23% 확률로 부정!! 리뷰입니다.
# 78.23% 확률로 부정!! 리뷰입니다.
# 70.98% 확률로 부정!! 리뷰입니다.
# 97.85% 확률로 부정!! 리뷰입니다.
# 76.87% 확률로 부정!! 리뷰입니다.
# 80.55% 확률로 부정!! 리뷰입니다.
# 91.00% 확률로 부정!! 리뷰입니다.
# 66.16% 확률로 부정!! 리뷰입니다.
# 88.78% 확률로 부정!! 리뷰입니다.
# 89.09% 확률로 부정!! 리뷰입니다.
# 97.07% 확률로 긍정^^ 리뷰입니다.
# 59.63% 확률로 부정!! 리뷰입니다.
# 96.39% 확률로 부정!! 리뷰입니다.
# 78.23% 확률로 부정!! 리뷰입니다.
# 72.89% 확률로 부정!! 리뷰입니다.
# 87.57% 확률로 긍정^^ 리뷰입니다.
# 84.45% 확률로 부정!! 리뷰입니다.
# 72.44% 확률로 부정!! 리뷰입니다.
# 92.58% 확률로 긍정^^ 리뷰입니다.
# 95.66% 확률로 긍정^^ 리뷰입니다.
# 77.94% 확률로 긍정^^ 리뷰입니다.
# 92.82% 확률로 부정!! 리뷰입니다.
# 69.82% 확률로 부정!! 리뷰입니다.
# 62.09% 확률로 부정!! 리뷰입니다.
# 86.89% 확률로 부정!! 리뷰입니다.
# 98.24% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 77.94% 확률로 긍정^^ 리뷰입니다.
# 97.07% 확률로 긍정^^ 리뷰입니다.
# 87.25% 확률로 긍정^^ 리뷰입니다.
# 83.81% 확률로 긍정^^ 리뷰입니다.
# 92.41% 확률로 부정!! 리뷰입니다.
# 95.30% 확률로 긍정^^ 리뷰입니다.
# 55.62% 확률로 부정!! 리뷰입니다.
# 83.91% 확률로 부정!! 리뷰입니다.
# 71.47% 확률로 부정!! 리뷰입니다.
# 99.51% 확률로 긍정^^ 리뷰입니다.
# 79.49% 확률로 부정!! 리뷰입니다.
# 90.88% 확률로 부정!! 리뷰입니다.
# 64.39% 확률로 부정!! 리뷰입니다.
# 95.22% 확률로 부정!! 리뷰입니다.
# 52.43% 확률로 긍정^^ 리뷰입니다.
# 74.32% 확률로 부정!! 리뷰입니다.
# 72.58% 확률로 긍정^^ 리뷰입니다.
# 72.19% 확률로 부정!! 리뷰입니다.
# 95.81% 확률로 부정!! 리뷰입니다.
# 81.31% 확률로 긍정^^ 리뷰입니다.
# 84.26% 확률로 긍정^^ 리뷰입니다.
# 92.68% 확률로 긍정^^ 리뷰입니다.
# 96.82% 확률로 긍정^^ 리뷰입니다.
# 95.87% 확률로 부정!! 리뷰입니다.
# 78.75% 확률로 부정!! 리뷰입니다.
# 72.56% 확률로 긍정^^ 리뷰입니다.
# 61.57% 확률로 긍정^^ 리뷰입니다.
# 91.19% 확률로 부정!! 리뷰입니다.
# 97.70% 확률로 부정!! 리뷰입니다.
# 98.47% 확률로 부정!! 리뷰입니다.
# 80.71% 확률로 부정!! 리뷰입니다.
# 85.87% 확률로 긍정^^ 리뷰입니다.
# 83.28% 확률로 긍정^^ 리뷰입니다.
# 93.67% 확률로 부정!! 리뷰입니다.
# 90.91% 확률로 긍정^^ 리뷰입니다.
# 66.11% 확률로 부정!! 리뷰입니다.
# 61.88% 확률로 부정!! 리뷰입니다.
# 89.56% 확률로 부정!! 리뷰입니다.
# 88.04% 확률로 부정!! 리뷰입니다.
# 79.02% 확률로 긍정^^ 리뷰입니다.
# 90.92% 확률로 긍정^^ 리뷰입니다.
# 71.11% 확률로 긍정^^ 리뷰입니다.
# 83.27% 확률로 긍정^^ 리뷰입니다.
# 86.82% 확률로 긍정^^ 리뷰입니다.
# 72.13% 확률로 부정!! 리뷰입니다.
# 89.66% 확률로 긍정^^ 리뷰입니다.
# 90.79% 확률로 긍정^^ 리뷰입니다.
# 94.54% 확률로 부정!! 리뷰입니다.
# 91.27% 확률로 긍정^^ 리뷰입니다.
# 84.17% 확률로 긍정^^ 리뷰입니다.
# 94.50% 확률로 긍정^^ 리뷰입니다.
# 95.05% 확률로 긍정^^ 리뷰입니다.
# 56.19% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 97.13% 확률로 부정!! 리뷰입니다.
# 80.85% 확률로 긍정^^ 리뷰입니다.
# 86.01% 확률로 부정!! 리뷰입니다.
# 92.50% 확률로 부정!! 리뷰입니다.
# 54.57% 확률로 부정!! 리뷰입니다.
# 62.90% 확률로 부정!! 리뷰입니다.
# 73.43% 확률로 부정!! 리뷰입니다.
# 97.97% 확률로 부정!! 리뷰입니다.
# 91.61% 확률로 부정!! 리뷰입니다.
# 88.37% 확률로 부정!! 리뷰입니다.
# 92.10% 확률로 부정!! 리뷰입니다.
# 69.25% 확률로 부정!! 리뷰입니다.
# 90.79% 확률로 긍정^^ 리뷰입니다.
# 84.17% 확률로 긍정^^ 리뷰입니다.
# 92.63% 확률로 긍정^^ 리뷰입니다.
# 80.54% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 69.40% 확률로 긍정^^ 리뷰입니다.
# 88.35% 확률로 부정!! 리뷰입니다.
# 84.09% 확률로 부정!! 리뷰입니다.
# 55.33% 확률로 긍정^^ 리뷰입니다.
# 75.44% 확률로 부정!! 리뷰입니다.
# 58.35% 확률로 긍정^^ 리뷰입니다.
# 85.76% 확률로 긍정^^ 리뷰입니다.
# 94.79% 확률로 긍정^^ 리뷰입니다.
# 76.36% 확률로 긍정^^ 리뷰입니다.
# 58.35% 확률로 긍정^^ 리뷰입니다.
# 51.50% 확률로 긍정^^ 리뷰입니다.
# 76.36% 확률로 긍정^^ 리뷰입니다.
# 62.45% 확률로 긍정^^ 리뷰입니다.
# 74.40% 확률로 부정!! 리뷰입니다.
# 51.50% 확률로 긍정^^ 리뷰입니다.
# 69.92% 확률로 긍정^^ 리뷰입니다.
# 98.92% 확률로 긍정^^ 리뷰입니다.
# 69.92% 확률로 긍정^^ 리뷰입니다.
# 76.49% 확률로 긍정^^ 리뷰입니다.
# 79.69% 확률로 긍정^^ 리뷰입니다.
# 69.92% 확률로 긍정^^ 리뷰입니다.
# 91.68% 확률로 부정!! 리뷰입니다.
# 90.27% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 98.60% 확률로 부정!! 리뷰입니다.
# 83.64% 확률로 긍정^^ 리뷰입니다.
# 64.42% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 64.72% 확률로 긍정^^ 리뷰입니다.
# 76.91% 확률로 부정!! 리뷰입니다.
# 62.97% 확률로 긍정^^ 리뷰입니다.
# 84.64% 확률로 부정!! 리뷰입니다.
# 59.36% 확률로 긍정^^ 리뷰입니다.
# 60.02% 확률로 긍정^^ 리뷰입니다.
# 64.72% 확률로 긍정^^ 리뷰입니다.
# 65.76% 확률로 부정!! 리뷰입니다.
# 55.00% 확률로 부정!! 리뷰입니다.
# 57.60% 확률로 부정!! 리뷰입니다.
# 98.68% 확률로 부정!! 리뷰입니다.
# 59.44% 확률로 긍정^^ 리뷰입니다.
# 92.75% 확률로 긍정^^ 리뷰입니다.
# 59.44% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 76.92% 확률로 부정!! 리뷰입니다.
# 64.36% 확률로 긍정^^ 리뷰입니다.
# 66.66% 확률로 긍정^^ 리뷰입니다.
# 54.60% 확률로 부정!! 리뷰입니다.
# 57.89% 확률로 긍정^^ 리뷰입니다.
# 97.82% 확률로 부정!! 리뷰입니다.
# 67.68% 확률로 부정!! 리뷰입니다.
# 57.89% 확률로 긍정^^ 리뷰입니다.
# 57.89% 확률로 긍정^^ 리뷰입니다.
# 63.31% 확률로 부정!! 리뷰입니다.
# 63.31% 확률로 부정!! 리뷰입니다.
# 67.68% 확률로 부정!! 리뷰입니다.
# 65.96% 확률로 긍정^^ 리뷰입니다.
# 76.98% 확률로 부정!! 리뷰입니다.
# 58.46% 확률로 부정!! 리뷰입니다.
# 65.14% 확률로 긍정^^ 리뷰입니다.
# 54.63% 확률로 부정!! 리뷰입니다.
# 91.88% 확률로 부정!! 리뷰입니다.
# 54.93% 확률로 긍정^^ 리뷰입니다.
# 96.91% 확률로 부정!! 리뷰입니다.
# 88.03% 확률로 긍정^^ 리뷰입니다.
# 65.14% 확률로 긍정^^ 리뷰입니다.
# 97.61% 확률로 부정!! 리뷰입니다.
# 65.14% 확률로 긍정^^ 리뷰입니다.
# 65.14% 확률로 긍정^^ 리뷰입니다.
# 98.34% 확률로 부정!! 리뷰입니다.
# 95.91% 확률로 부정!! 리뷰입니다.
# 85.84% 확률로 부정!! 리뷰입니다.
# 67.81% 확률로 긍정^^ 리뷰입니다.
# 84.42% 확률로 긍정^^ 리뷰입니다.
# 78.09% 확률로 긍정^^ 리뷰입니다.
# 67.12% 확률로 긍정^^ 리뷰입니다.
# 73.29% 확률로 긍정^^ 리뷰입니다.
# 84.42% 확률로 긍정^^ 리뷰입니다.
# 90.92% 확률로 긍정^^ 리뷰입니다.
# 83.78% 확률로 긍정^^ 리뷰입니다.
# 65.16% 확률로 긍정^^ 리뷰입니다.
# 73.29% 확률로 긍정^^ 리뷰입니다.
# 65.16% 확률로 긍정^^ 리뷰입니다.
# 66.48% 확률로 부정!! 리뷰입니다.
# 61.51% 확률로 긍정^^ 리뷰입니다.
# 58.80% 확률로 부정!! 리뷰입니다.
# 96.64% 확률로 긍정^^ 리뷰입니다.
# 94.91% 확률로 부정!! 리뷰입니다.
# 73.29% 확률로 긍정^^ 리뷰입니다.
# 97.10% 확률로 긍정^^ 리뷰입니다.
# 96.65% 확률로 긍정^^ 리뷰입니다.
# 79.45% 확률로 부정!! 리뷰입니다.
# 93.66% 확률로 부정!! 리뷰입니다.
# 77.08% 확률로 부정!! 리뷰입니다.
# 72.27% 확률로 부정!! 리뷰입니다.
# 98.28% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 95.06% 확률로 부정!! 리뷰입니다.
# 66.56% 확률로 부정!! 리뷰입니다.
# 61.73% 확률로 긍정^^ 리뷰입니다.
# 78.82% 확률로 부정!! 리뷰입니다.
# 89.29% 확률로 긍정^^ 리뷰입니다.
# 77.08% 확률로 부정!! 리뷰입니다.
# 94.09% 확률로 긍정^^ 리뷰입니다.
# 88.10% 확률로 부정!! 리뷰입니다.
# 72.74% 확률로 부정!! 리뷰입니다.
# 81.57% 확률로 부정!! 리뷰입니다.
# 98.45% 확률로 긍정^^ 리뷰입니다.
# 81.39% 확률로 부정!! 리뷰입니다.
# 50.95% 확률로 긍정^^ 리뷰입니다.
# 59.12% 확률로 긍정^^ 리뷰입니다.
# 62.74% 확률로 긍정^^ 리뷰입니다.
# 65.57% 확률로 긍정^^ 리뷰입니다.
# 78.47% 확률로 긍정^^ 리뷰입니다.
# 72.49% 확률로 긍정^^ 리뷰입니다.
# 96.45% 확률로 긍정^^ 리뷰입니다.
# 93.39% 확률로 부정!! 리뷰입니다.
# 91.81% 확률로 부정!! 리뷰입니다.
# 87.14% 확률로 부정!! 리뷰입니다.
# 67.39% 확률로 부정!! 리뷰입니다.
# 98.30% 확률로 부정!! 리뷰입니다.
# 80.98% 확률로 긍정^^ 리뷰입니다.
# 82.34% 확률로 부정!! 리뷰입니다.
# 82.51% 확률로 긍정^^ 리뷰입니다.
# 77.41% 확률로 긍정^^ 리뷰입니다.
# 72.19% 확률로 긍정^^ 리뷰입니다.
# 86.81% 확률로 부정!! 리뷰입니다.
# 80.14% 확률로 부정!! 리뷰입니다.
# 90.50% 확률로 부정!! 리뷰입니다.
# 80.07% 확률로 부정!! 리뷰입니다.
# 96.71% 확률로 부정!! 리뷰입니다.
# 99.74% 확률로 부정!! 리뷰입니다.
# 96.14% 확률로 부정!! 리뷰입니다.
# 88.79% 확률로 부정!! 리뷰입니다.
# 95.95% 확률로 부정!! 리뷰입니다.
# 82.26% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 94.25% 확률로 부정!! 리뷰입니다.
# 91.56% 확률로 부정!! 리뷰입니다.
# 70.73% 확률로 긍정^^ 리뷰입니다.
# 98.89% 확률로 부정!! 리뷰입니다.
# 75.68% 확률로 부정!! 리뷰입니다.
# 98.01% 확률로 긍정^^ 리뷰입니다.
# 85.74% 확률로 부정!! 리뷰입니다.
# 77.71% 확률로 긍정^^ 리뷰입니다.
# 75.33% 확률로 긍정^^ 리뷰입니다.
# 97.64% 확률로 부정!! 리뷰입니다.
# 92.04% 확률로 부정!! 리뷰입니다.
# 97.17% 확률로 부정!! 리뷰입니다.
# 84.20% 확률로 부정!! 리뷰입니다.
# 97.64% 확률로 부정!! 리뷰입니다.
# 52.92% 확률로 부정!! 리뷰입니다.
# 92.01% 확률로 부정!! 리뷰입니다.
# 98.19% 확률로 부정!! 리뷰입니다.
# 52.89% 확률로 긍정^^ 리뷰입니다.
# 75.11% 확률로 긍정^^ 리뷰입니다.
# 62.18% 확률로 부정!! 리뷰입니다.
# 94.54% 확률로 부정!! 리뷰입니다.
# 93.96% 확률로 부정!! 리뷰입니다.
# 88.43% 확률로 부정!! 리뷰입니다.
# 99.03% 확률로 부정!! 리뷰입니다.
# 54.92% 확률로 긍정^^ 리뷰입니다.
# 98.49% 확률로 부정!! 리뷰입니다.
# 67.84% 확률로 긍정^^ 리뷰입니다.
# 54.29% 확률로 부정!! 리뷰입니다.
# 86.82% 확률로 부정!! 리뷰입니다.
# 98.89% 확률로 부정!! 리뷰입니다.
# 90.03% 확률로 긍정^^ 리뷰입니다.
# 66.03% 확률로 부정!! 리뷰입니다.
# 62.09% 확률로 부정!! 리뷰입니다.
# 57.43% 확률로 긍정^^ 리뷰입니다.
# 86.96% 확률로 긍정^^ 리뷰입니다.
# 58.28% 확률로 부정!! 리뷰입니다.
# 99.05% 확률로 긍정^^ 리뷰입니다.
# 90.27% 확률로 긍정^^ 리뷰입니다.
# 97.11% 확률로 부정!! 리뷰입니다.
# 95.33% 확률로 부정!! 리뷰입니다.
# 74.77% 확률로 부정!! 리뷰입니다.
# 72.73% 확률로 부정!! 리뷰입니다.
# 58.40% 확률로 긍정^^ 리뷰입니다.
# 96.34% 확률로 부정!! 리뷰입니다.
# 85.27% 확률로 긍정^^ 리뷰입니다.
# 86.17% 확률로 긍정^^ 리뷰입니다.
# 96.00% 확률로 긍정^^ 리뷰입니다.
# 86.51% 확률로 부정!! 리뷰입니다.
# 55.51% 확률로 긍정^^ 리뷰입니다.
# 84.75% 확률로 긍정^^ 리뷰입니다.
# 99.57% 확률로 부정!! 리뷰입니다.
# 97.55% 확률로 부정!! 리뷰입니다.
# 98.56% 확률로 부정!! 리뷰입니다.
# 93.38% 확률로 부정!! 리뷰입니다.
# 98.39% 확률로 부정!! 리뷰입니다.
# 57.95% 확률로 부정!! 리뷰입니다.
# 90.27% 확률로 긍정^^ 리뷰입니다.
# 57.27% 확률로 부정!! 리뷰입니다.
# 97.86% 확률로 부정!! 리뷰입니다.
# 98.39% 확률로 부정!! 리뷰입니다.
# 68.12% 확률로 긍정^^ 리뷰입니다.
# 97.87% 확률로 부정!! 리뷰입니다.
# 98.18% 확률로 부정!! 리뷰입니다.
# 97.02% 확률로 부정!! 리뷰입니다.
# 93.38% 확률로 부정!! 리뷰입니다.
# 94.32% 확률로 부정!! 리뷰입니다.
# 69.43% 확률로 부정!! 리뷰입니다.
# 91.58% 확률로 부정!! 리뷰입니다.
# 64.06% 확률로 부정!! 리뷰입니다.
# 87.13% 확률로 부정!! 리뷰입니다.
# 94.05% 확률로 부정!! 리뷰입니다.
# 60.86% 확률로 부정!! 리뷰입니다.
# 87.39% 확률로 부정!! 리뷰입니다.
# 90.05% 확률로 부정!! 리뷰입니다.
# 90.54% 확률로 부정!! 리뷰입니다.
# 95.38% 확률로 부정!! 리뷰입니다.
# 85.43% 확률로 부정!! 리뷰입니다.
# 86.04% 확률로 부정!! 리뷰입니다.
# 93.70% 확률로 부정!! 리뷰입니다.
# 89.90% 확률로 부정!! 리뷰입니다.
# 94.89% 확률로 부정!! 리뷰입니다.
# 95.59% 확률로 부정!! 리뷰입니다.
# 85.82% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 54.95% 확률로 부정!! 리뷰입니다.
# 81.29% 확률로 긍정^^ 리뷰입니다.
# 63.44% 확률로 부정!! 리뷰입니다.
# 97.31% 확률로 긍정^^ 리뷰입니다.
# 79.29% 확률로 부정!! 리뷰입니다.
# 89.93% 확률로 부정!! 리뷰입니다.
# 99.12% 확률로 부정!! 리뷰입니다.
# 98.49% 확률로 긍정^^ 리뷰입니다.
# 54.76% 확률로 긍정^^ 리뷰입니다.
# 66.12% 확률로 긍정^^ 리뷰입니다.
# 70.02% 확률로 긍정^^ 리뷰입니다.
# 98.41% 확률로 부정!! 리뷰입니다.
# 71.76% 확률로 긍정^^ 리뷰입니다.
# 67.28% 확률로 긍정^^ 리뷰입니다.
# 85.53% 확률로 부정!! 리뷰입니다.
# 67.12% 확률로 긍정^^ 리뷰입니다.
# 53.66% 확률로 부정!! 리뷰입니다.
# 96.30% 확률로 부정!! 리뷰입니다.
# 96.44% 확률로 부정!! 리뷰입니다.
# 90.27% 확률로 긍정^^ 리뷰입니다.
# 95.30% 확률로 긍정^^ 리뷰입니다.
# 62.92% 확률로 부정!! 리뷰입니다.
# 88.74% 확률로 부정!! 리뷰입니다.
# 55.35% 확률로 부정!! 리뷰입니다.
# 93.56% 확률로 부정!! 리뷰입니다.
# 92.88% 확률로 부정!! 리뷰입니다.
# 90.27% 확률로 긍정^^ 리뷰입니다.
# 90.27% 확률로 긍정^^ 리뷰입니다.
# 90.27% 확률로 긍정^^ 리뷰입니다.
# 67.71% 확률로 긍정^^ 리뷰입니다.
# 70.82% 확률로 부정!! 리뷰입니다.
# 81.08% 확률로 부정!! 리뷰입니다.
# 63.03% 확률로 긍정^^ 리뷰입니다.
# 86.73% 확률로 부정!! 리뷰입니다.
# 98.19% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 89.59% 확률로 부정!! 리뷰입니다.
# 86.04% 확률로 부정!! 리뷰입니다.
# 53.17% 확률로 긍정^^ 리뷰입니다.
# 66.35% 확률로 부정!! 리뷰입니다.
# 96.98% 확률로 부정!! 리뷰입니다.
# 64.08% 확률로 부정!! 리뷰입니다.
# 83.98% 확률로 긍정^^ 리뷰입니다.
# 85.76% 확률로 부정!! 리뷰입니다.
# 61.50% 확률로 부정!! 리뷰입니다.
# 66.12% 확률로 긍정^^ 리뷰입니다.
# 67.57% 확률로 부정!! 리뷰입니다.
# 92.36% 확률로 부정!! 리뷰입니다.
# 88.22% 확률로 부정!! 리뷰입니다.
# 87.52% 확률로 부정!! 리뷰입니다.
# 53.87% 확률로 부정!! 리뷰입니다.
# 98.77% 확률로 부정!! 리뷰입니다.
# 81.34% 확률로 부정!! 리뷰입니다.
# 78.81% 확률로 부정!! 리뷰입니다.
# 81.59% 확률로 부정!! 리뷰입니다.
# 66.95% 확률로 부정!! 리뷰입니다.
# 69.13% 확률로 긍정^^ 리뷰입니다.
# 97.56% 확률로 긍정^^ 리뷰입니다.
# 97.34% 확률로 부정!! 리뷰입니다.
# 87.73% 확률로 부정!! 리뷰입니다.
# 88.88% 확률로 부정!! 리뷰입니다.
# 55.79% 확률로 부정!! 리뷰입니다.
# 81.26% 확률로 긍정^^ 리뷰입니다.
# 50.08% 확률로 부정!! 리뷰입니다.
# 95.89% 확률로 부정!! 리뷰입니다.
# 71.96% 확률로 부정!! 리뷰입니다.
# 92.54% 확률로 긍정^^ 리뷰입니다.
# 71.96% 확률로 부정!! 리뷰입니다.
# 87.17% 확률로 부정!! 리뷰입니다.
# 57.47% 확률로 긍정^^ 리뷰입니다.
# 91.22% 확률로 부정!! 리뷰입니다.
# 89.45% 확률로 부정!! 리뷰입니다.
# 94.32% 확률로 부정!! 리뷰입니다.
# 53.55% 확률로 긍정^^ 리뷰입니다.
# 64.54% 확률로 부정!! 리뷰입니다.
# 91.56% 확률로 부정!! 리뷰입니다.
# 97.38% 확률로 긍정^^ 리뷰입니다.
# 98.24% 확률로 긍정^^ 리뷰입니다.
# 80.94% 확률로 긍정^^ 리뷰입니다.
# 73.96% 확률로 부정!! 리뷰입니다.
# 69.63% 확률로 긍정^^ 리뷰입니다.
# 93.05% 확률로 부정!! 리뷰입니다.
# 95.11% 확률로 긍정^^ 리뷰입니다.
# 95.24% 확률로 긍정^^ 리뷰입니다.
# 95.72% 확률로 긍정^^ 리뷰입니다.
# 56.75% 확률로 부정!! 리뷰입니다.
# 56.75% 확률로 부정!! 리뷰입니다.
# 69.03% 확률로 긍정^^ 리뷰입니다.
# 69.03% 확률로 긍정^^ 리뷰입니다.
# 76.70% 확률로 부정!! 리뷰입니다.
# 61.63% 확률로 부정!! 리뷰입니다.
# 76.92% 확률로 부정!! 리뷰입니다.
# 95.56% 확률로 긍정^^ 리뷰입니다.
# 93.53% 확률로 부정!! 리뷰입니다.
# 77.12% 확률로 부정!! 리뷰입니다.
# 87.13% 확률로 부정!! 리뷰입니다.
# 89.36% 확률로 부정!! 리뷰입니다.
# 62.85% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 50.76% 확률로 부정!! 리뷰입니다.
# 88.26% 확률로 긍정^^ 리뷰입니다.
# 88.70% 확률로 긍정^^ 리뷰입니다.
# 95.84% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 78.78% 확률로 부정!! 리뷰입니다.
# 89.18% 확률로 긍정^^ 리뷰입니다.
# 93.48% 확률로 부정!! 리뷰입니다.
# 70.63% 확률로 부정!! 리뷰입니다.
# 91.37% 확률로 긍정^^ 리뷰입니다.
# 82.55% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 76.88% 확률로 긍정^^ 리뷰입니다.
# 98.96% 확률로 긍정^^ 리뷰입니다.
# 96.40% 확률로 긍정^^ 리뷰입니다.
# 89.59% 확률로 긍정^^ 리뷰입니다.
# 89.59% 확률로 긍정^^ 리뷰입니다.
# 90.55% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 67.85% 확률로 부정!! 리뷰입니다.
# 81.83% 확률로 긍정^^ 리뷰입니다.
# 91.15% 확률로 긍정^^ 리뷰입니다.
# 60.19% 확률로 부정!! 리뷰입니다.
# 79.09% 확률로 부정!! 리뷰입니다.
# 84.71% 확률로 부정!! 리뷰입니다.
# 90.80% 확률로 부정!! 리뷰입니다.
# 96.46% 확률로 긍정^^ 리뷰입니다.
# 96.32% 확률로 부정!! 리뷰입니다.
# 58.76% 확률로 긍정^^ 리뷰입니다.
# 89.60% 확률로 긍정^^ 리뷰입니다.
# 79.44% 확률로 부정!! 리뷰입니다.
# 97.92% 확률로 긍정^^ 리뷰입니다.
# 93.67% 확률로 긍정^^ 리뷰입니다.
# 90.68% 확률로 긍정^^ 리뷰입니다.
# 52.28% 확률로 부정!! 리뷰입니다.
# 52.69% 확률로 부정!! 리뷰입니다.
# 98.63% 확률로 부정!! 리뷰입니다.
# 83.73% 확률로 부정!! 리뷰입니다.
# 61.70% 확률로 긍정^^ 리뷰입니다.
# 77.43% 확률로 긍정^^ 리뷰입니다.
# 93.42% 확률로 긍정^^ 리뷰입니다.
# 67.88% 확률로 긍정^^ 리뷰입니다.
# 55.33% 확률로 긍정^^ 리뷰입니다.
# 59.36% 확률로 긍정^^ 리뷰입니다.
# 75.82% 확률로 부정!! 리뷰입니다.
# 86.19% 확률로 부정!! 리뷰입니다.
# 86.19% 확률로 부정!! 리뷰입니다.
# 63.42% 확률로 부정!! 리뷰입니다.
# 84.77% 확률로 부정!! 리뷰입니다.
# 57.08% 확률로 부정!! 리뷰입니다.
# 51.03% 확률로 부정!! 리뷰입니다.
# 78.49% 확률로 부정!! 리뷰입니다.
# 72.00% 확률로 부정!! 리뷰입니다.
# 63.44% 확률로 부정!! 리뷰입니다.
# 64.77% 확률로 부정!! 리뷰입니다.
# 84.24% 확률로 부정!! 리뷰입니다.
# 65.86% 확률로 부정!! 리뷰입니다.
# 86.85% 확률로 긍정^^ 리뷰입니다.
# 59.48% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 91.91% 확률로 부정!! 리뷰입니다.
# 53.09% 확률로 부정!! 리뷰입니다.
# 97.17% 확률로 부정!! 리뷰입니다.
# 92.25% 확률로 부정!! 리뷰입니다.
# 72.40% 확률로 긍정^^ 리뷰입니다.
# 59.89% 확률로 긍정^^ 리뷰입니다.
# 95.13% 확률로 부정!! 리뷰입니다.
# 90.05% 확률로 긍정^^ 리뷰입니다.
# 82.97% 확률로 긍정^^ 리뷰입니다.
# 63.80% 확률로 부정!! 리뷰입니다.
# 97.58% 확률로 긍정^^ 리뷰입니다.
# 92.28% 확률로 부정!! 리뷰입니다.
# 94.77% 확률로 부정!! 리뷰입니다.
# 92.49% 확률로 부정!! 리뷰입니다.
# 53.59% 확률로 부정!! 리뷰입니다.
# 68.54% 확률로 긍정^^ 리뷰입니다.
# 97.74% 확률로 부정!! 리뷰입니다.
# 55.04% 확률로 긍정^^ 리뷰입니다.
# 95.09% 확률로 긍정^^ 리뷰입니다.
# 69.46% 확률로 긍정^^ 리뷰입니다.
# 69.46% 확률로 긍정^^ 리뷰입니다.
# 71.84% 확률로 긍정^^ 리뷰입니다.
# 67.72% 확률로 긍정^^ 리뷰입니다.
# 54.49% 확률로 긍정^^ 리뷰입니다.
# 94.54% 확률로 부정!! 리뷰입니다.
# 82.73% 확률로 긍정^^ 리뷰입니다.
# 84.88% 확률로 긍정^^ 리뷰입니다.
# 88.29% 확률로 부정!! 리뷰입니다.
# 74.18% 확률로 긍정^^ 리뷰입니다.
# 80.50% 확률로 긍정^^ 리뷰입니다.
# 55.25% 확률로 긍정^^ 리뷰입니다.
# 85.55% 확률로 긍정^^ 리뷰입니다.
# 71.61% 확률로 부정!! 리뷰입니다.
# 90.99% 확률로 긍정^^ 리뷰입니다.
# 88.29% 확률로 부정!! 리뷰입니다.
# 88.27% 확률로 긍정^^ 리뷰입니다.
# 82.97% 확률로 긍정^^ 리뷰입니다.
# 86.76% 확률로 긍정^^ 리뷰입니다.
# 98.14% 확률로 긍정^^ 리뷰입니다.
# 71.84% 확률로 긍정^^ 리뷰입니다.
# 77.26% 확률로 긍정^^ 리뷰입니다.
# 89.03% 확률로 부정!! 리뷰입니다.
# 92.58% 확률로 부정!! 리뷰입니다.
# 82.19% 확률로 긍정^^ 리뷰입니다.
# 53.80% 확률로 긍정^^ 리뷰입니다.
# 91.38% 확률로 부정!! 리뷰입니다.
# 90.16% 확률로 부정!! 리뷰입니다.
# 51.12% 확률로 부정!! 리뷰입니다.
# 88.28% 확률로 부정!! 리뷰입니다.
# 82.05% 확률로 긍정^^ 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 71.44% 확률로 긍정^^ 리뷰입니다.
# 59.64% 확률로 부정!! 리뷰입니다.
# 75.45% 확률로 부정!! 리뷰입니다.
# 95.05% 확률로 긍정^^ 리뷰입니다.
# 78.35% 확률로 긍정^^ 리뷰입니다.
# 60.88% 확률로 긍정^^ 리뷰입니다.
# 88.29% 확률로 부정!! 리뷰입니다.
# 84.43% 확률로 긍정^^ 리뷰입니다.
# 69.28% 확률로 긍정^^ 리뷰입니다.
# 83.65% 확률로 부정!! 리뷰입니다.
# 72.84% 확률로 부정!! 리뷰입니다.
# 86.84% 확률로 긍정^^ 리뷰입니다.
# 61.55% 확률로 부정!! 리뷰입니다.
# 85.73% 확률로 부정!! 리뷰입니다.
# 73.88% 확률로 긍정^^ 리뷰입니다.
# 58.99% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 86.90% 확률로 부정!! 리뷰입니다.
# 95.35% 확률로 부정!! 리뷰입니다.
# 93.77% 확률로 부정!! 리뷰입니다.
# 83.19% 확률로 긍정^^ 리뷰입니다.
# 83.51% 확률로 부정!! 리뷰입니다.
# 60.76% 확률로 긍정^^ 리뷰입니다.
# 60.21% 확률로 긍정^^ 리뷰입니다.
# 56.57% 확률로 긍정^^ 리뷰입니다.
# 66.00% 확률로 부정!! 리뷰입니다.
# 82.35% 확률로 부정!! 리뷰입니다.
# 68.48% 확률로 부정!! 리뷰입니다.
# 94.85% 확률로 긍정^^ 리뷰입니다.
# 79.20% 확률로 부정!! 리뷰입니다.
# 86.63% 확률로 부정!! 리뷰입니다.
# 71.38% 확률로 부정!! 리뷰입니다.
# 53.38% 확률로 부정!! 리뷰입니다.
# 58.95% 확률로 긍정^^ 리뷰입니다.
# 93.63% 확률로 부정!! 리뷰입니다.
# 65.86% 확률로 부정!! 리뷰입니다.
# 97.61% 확률로 부정!! 리뷰입니다.
# 73.93% 확률로 부정!! 리뷰입니다.
# 73.93% 확률로 부정!! 리뷰입니다.
# 60.70% 확률로 부정!! 리뷰입니다.
# 89.91% 확률로 긍정^^ 리뷰입니다.
# 93.21% 확률로 긍정^^ 리뷰입니다.
# 62.63% 확률로 부정!! 리뷰입니다.
# 65.86% 확률로 부정!! 리뷰입니다.
# 91.61% 확률로 부정!! 리뷰입니다.
# 77.01% 확률로 부정!! 리뷰입니다.
# 98.85% 확률로 부정!! 리뷰입니다.
# 80.21% 확률로 부정!! 리뷰입니다.
# 65.43% 확률로 긍정^^ 리뷰입니다.
# 89.71% 확률로 부정!! 리뷰입니다.
# 64.02% 확률로 부정!! 리뷰입니다.
# 93.73% 확률로 부정!! 리뷰입니다.
# 85.47% 확률로 긍정^^ 리뷰입니다.
# 54.50% 확률로 긍정^^ 리뷰입니다.
# 50.21% 확률로 긍정^^ 리뷰입니다.
# 72.40% 확률로 긍정^^ 리뷰입니다.
# 66.71% 확률로 긍정^^ 리뷰입니다.
# 64.23% 확률로 부정!! 리뷰입니다.
# 54.96% 확률로 긍정^^ 리뷰입니다.
# 60.03% 확률로 긍정^^ 리뷰입니다.
# 81.46% 확률로 부정!! 리뷰입니다.
# 98.53% 확률로 부정!! 리뷰입니다.
# 87.48% 확률로 부정!! 리뷰입니다.
# 86.30% 확률로 긍정^^ 리뷰입니다.
# 69.35% 확률로 긍정^^ 리뷰입니다.
# 52.72% 확률로 부정!! 리뷰입니다.
# 52.72% 확률로 부정!! 리뷰입니다.
# 95.12% 확률로 긍정^^ 리뷰입니다.
# 69.35% 확률로 긍정^^ 리뷰입니다.
# 82.89% 확률로 부정!! 리뷰입니다.
# 90.50% 확률로 긍정^^ 리뷰입니다.
# 99.25% 확률로 부정!! 리뷰입니다.
# 62.12% 확률로 부정!! 리뷰입니다.
# 81.03% 확률로 부정!! 리뷰입니다.
# 50.62% 확률로 긍정^^ 리뷰입니다.
# 64.01% 확률로 부정!! 리뷰입니다.
# 68.34% 확률로 부정!! 리뷰입니다.
# 63.38% 확률로 긍정^^ 리뷰입니다.
# 77.87% 확률로 부정!! 리뷰입니다.
# 94.38% 확률로 부정!! 리뷰입니다.
# 63.32% 확률로 부정!! 리뷰입니다.
# 98.48% 확률로 부정!! 리뷰입니다.
# 68.01% 확률로 긍정^^ 리뷰입니다.
# 75.74% 확률로 부정!! 리뷰입니다.
# 53.19% 확률로 부정!! 리뷰입니다.
# 73.70% 확률로 긍정^^ 리뷰입니다.
# 98.43% 확률로 부정!! 리뷰입니다.
# 92.73% 확률로 부정!! 리뷰입니다.
# 95.30% 확률로 긍정^^ 리뷰입니다.
# 69.80% 확률로 부정!! 리뷰입니다.
# 63.32% 확률로 부정!! 리뷰입니다.
# 57.37% 확률로 긍정^^ 리뷰입니다.
# 79.63% 확률로 부정!! 리뷰입니다.
# 71.42% 확률로 부정!! 리뷰입니다.
# 63.32% 확률로 부정!! 리뷰입니다.
# 69.25% 확률로 부정!! 리뷰입니다.
# 81.28% 확률로 부정!! 리뷰입니다.
# 63.32% 확률로 부정!! 리뷰입니다.
# 92.27% 확률로 부정!! 리뷰입니다.
# 70.24% 확률로 긍정^^ 리뷰입니다.
# 75.58% 확률로 긍정^^ 리뷰입니다.
# 97.06% 확률로 부정!! 리뷰입니다.
# 94.57% 확률로 부정!! 리뷰입니다.
# 96.33% 확률로 부정!! 리뷰입니다.
# 53.28% 확률로 부정!! 리뷰입니다.
# 65.67% 확률로 부정!! 리뷰입니다.
# 68.85% 확률로 부정!! 리뷰입니다.
# 97.85% 확률로 긍정^^ 리뷰입니다.
# 63.91% 확률로 부정!! 리뷰입니다.
# 65.86% 확률로 부정!! 리뷰입니다.
# 87.73% 확률로 부정!! 리뷰입니다.
# 80.98% 확률로 부정!! 리뷰입니다.
# 86.87% 확률로 부정!! 리뷰입니다.
# 75.31% 확률로 부정!! 리뷰입니다.
# 50.82% 확률로 부정!! 리뷰입니다.
# 94.96% 확률로 부정!! 리뷰입니다.
# 69.40% 확률로 긍정^^ 리뷰입니다.
# 57.55% 확률로 긍정^^ 리뷰입니다.
# 63.32% 확률로 부정!! 리뷰입니다.
# 80.64% 확률로 부정!! 리뷰입니다.
# 99.04% 확률로 부정!! 리뷰입니다.
# 72.62% 확률로 부정!! 리뷰입니다.
# 63.32% 확률로 부정!! 리뷰입니다.
# 74.69% 확률로 부정!! 리뷰입니다.
# 50.01% 확률로 부정!! 리뷰입니다.
# 85.67% 확률로 부정!! 리뷰입니다.
# 79.71% 확률로 부정!! 리뷰입니다.
# 91.62% 확률로 부정!! 리뷰입니다.
# 85.71% 확률로 긍정^^ 리뷰입니다.
# 69.39% 확률로 부정!! 리뷰입니다.
# 58.65% 확률로 부정!! 리뷰입니다.
# 67.29% 확률로 긍정^^ 리뷰입니다.
# 82.48% 확률로 긍정^^ 리뷰입니다.
# 56.06% 확률로 부정!! 리뷰입니다.
# 88.37% 확률로 부정!! 리뷰입니다.
# ...
# 83.21% 확률로 부정!! 리뷰입니다.
# 68.48% 확률로 부정!! 리뷰입니다.
# 71.98% 확률로 부정!! 리뷰입니다.
# 50.39% 확률로 부정!! 리뷰입니다.
# 99.09% 확률로 부정!! 리뷰입니다.
# 82.37% 확률로 부정!! 리뷰입니다.
# 86.08% 확률로 부정!! 리뷰입니다.
# 93.40% 확률로 부정!! 리뷰입니다.
# 80.20% 확률로 부정!! 리뷰입니다.
# 63.91% 확률로 긍정^^ 리뷰입니다.
# 50.44% 확률로 부정!! 리뷰입니다.
# 99.67% 확률로 부정!! 리뷰입니다.
# 94.04% 확률로 부정!! 리뷰입니다.
# 99.02% 확률로 부정!! 리뷰입니다.
# 91.56% 확률로 부정!! 리뷰입니다.
# 86.20% 확률로 부정!! 리뷰입니다.
# 85.18% 확률로 부정!! 리뷰입니다.
# 93.26% 확률로 부정!! 리뷰입니다.
# 86.92% 확률로 부정!! 리뷰입니다.
# 99.39% 확률로 부정!! 리뷰입니다.
# 86.09% 확률로 부정!! 리뷰입니다.
# 96.10% 확률로 부정!! 리뷰입니다.
# 84.49% 확률로 부정!! 리뷰입니다.
# 79.86% 확률로 부정!! 리뷰입니다.
# 96.39% 확률로 부정!! 리뷰입니다.
# 95.94% 확률로 부정!! 리뷰입니다.
# 86.09% 확률로 긍정^^ 리뷰입니다.
# 98.78% 확률로 부정!! 리뷰입니다.
# 94.67% 확률로 부정!! 리뷰입니다.
# 86.37% 확률로 부정!! 리뷰입니다.
# 57.27% 확률로 부정!! 리뷰입니다.
# 96.45% 확률로 부정!! 리뷰입니다.
# 96.66% 확률로 부정!! 리뷰입니다.
# 72.61% 확률로 부정!! 리뷰입니다.
# 95.45% 확률로 부정!! 리뷰입니다.
# 76.61% 확률로 부정!! 리뷰입니다.
# 85.09% 확률로 부정!! 리뷰입니다.
# 96.58% 확률로 긍정^^ 리뷰입니다.
# 92.85% 확률로 부정!! 리뷰입니다.
# 97.63% 확률로 부정!! 리뷰입니다.
# 80.30% 확률로 부정!! 리뷰입니다.
# 64.89% 확률로 긍정^^ 리뷰입니다.
# 62.82% 확률로 긍정^^ 리뷰입니다.
# 96.92% 확률로 부정!! 리뷰입니다.
# 91.45% 확률로 부정!! 리뷰입니다.
# 86.59% 확률로 부정!! 리뷰입니다.
# 66.72% 확률로 부정!! 리뷰입니다.
# 71.57% 확률로 긍정^^ 리뷰입니다.
# 65.63% 확률로 긍정^^ 리뷰입니다.
# 94.90% 확률로 부정!! 리뷰입니다.
# 88.21% 확률로 부정!! 리뷰입니다.
# 94.95% 확률로 부정!! 리뷰입니다.
# 77.78% 확률로 부정!! 리뷰입니다.
# 93.51% 확률로 부정!! 리뷰입니다.
# 97.52% 확률로 부정!! 리뷰입니다.
# 97.69% 확률로 부정!! 리뷰입니다.
# 98.52% 확률로 부정!! 리뷰입니다.
# 94.83% 확률로 부정!! 리뷰입니다.
# 83.43% 확률로 부정!! 리뷰입니다.
# 98.66% 확률로 부정!! 리뷰입니다.
# 93.81% 확률로 부정!! 리뷰입니다.
# 84.07% 확률로 긍정^^ 리뷰입니다.
# 90.96% 확률로 부정!! 리뷰입니다.
# 96.11% 확률로 부정!! 리뷰입니다.
# 98.45% 확률로 부정!! 리뷰입니다.
# 98.67% 확률로 부정!! 리뷰입니다.
# 99.18% 확률로 긍정^^ 리뷰입니다.
# 99.40% 확률로 부정!! 리뷰입니다.
# 66.20% 확률로 긍정^^ 리뷰입니다.
# 87.26% 확률로 부정!! 리뷰입니다.
# 90.75% 확률로 부정!! 리뷰입니다.
# 98.48% 확률로 부정!! 리뷰입니다.
# 98.89% 확률로 긍정^^ 리뷰입니다.
# 89.98% 확률로 부정!! 리뷰입니다.
# 94.31% 확률로 부정!! 리뷰입니다.
# 91.96% 확률로 부정!! 리뷰입니다.
# 63.60% 확률로 부정!! 리뷰입니다.
# 99.01% 확률로 부정!! 리뷰입니다.
# 70.35% 확률로 긍정^^ 리뷰입니다.
# 92.81% 확률로 부정!! 리뷰입니다.
# 97.04% 확률로 긍정^^ 리뷰입니다.
# 98.84% 확률로 부정!! 리뷰입니다.
# 72.93% 확률로 긍정^^ 리뷰입니다.
# 92.18% 확률로 부정!! 리뷰입니다.
# 85.99% 확률로 부정!! 리뷰입니다.
# 57.51% 확률로 긍정^^ 리뷰입니다.
# 97.89% 확률로 부정!! 리뷰입니다.
# 73.40% 확률로 부정!! 리뷰입니다.
# 87.11% 확률로 부정!! 리뷰입니다.
# 95.12% 확률로 부정!! 리뷰입니다.
# 87.58% 확률로 부정!! 리뷰입니다.
# 96.95% 확률로 부정!! 리뷰입니다.
# 82.90% 확률로 부정!! 리뷰입니다.
# 60.27% 확률로 부정!! 리뷰입니다.
# 94.05% 확률로 부정!! 리뷰입니다.
# 89.96% 확률로 부정!! 리뷰입니다.
# 89.09% 확률로 부정!! 리뷰입니다.
# 96.67% 확률로 부정!! 리뷰입니다.
# 66.05% 확률로 부정!! 리뷰입니다.
# 82.54% 확률로 부정!! 리뷰입니다.
# 98.83% 확률로 부정!! 리뷰입니다.
# 93.23% 확률로 부정!! 리뷰입니다.
# 74.08% 확률로 부정!! 리뷰입니다.
# 99.14% 확률로 부정!! 리뷰입니다.
# 95.98% 확률로 부정!! 리뷰입니다.
# 82.25% 확률로 긍정^^ 리뷰입니다.
# 88.02% 확률로 부정!! 리뷰입니다.
# 83.18% 확률로 부정!! 리뷰입니다.
# 70.19% 확률로 부정!! 리뷰입니다.
# 85.74% 확률로 부정!! 리뷰입니다.
# 77.95% 확률로 부정!! 리뷰입니다.
# 65.49% 확률로 부정!! 리뷰입니다.
# 96.53% 확률로 긍정^^ 리뷰입니다.
# 95.91% 확률로 부정!! 리뷰입니다.
# 97.43% 확률로 부정!! 리뷰입니다.
# 99.56% 확률로 부정!! 리뷰입니다.
# 96.83% 확률로 부정!! 리뷰입니다.
# 68.46% 확률로 부정!! 리뷰입니다.
# 99.38% 확률로 부정!! 리뷰입니다.
# 99.11% 확률로 부정!! 리뷰입니다.
# 84.84% 확률로 긍정^^ 리뷰입니다.
# 97.73% 확률로 부정!! 리뷰입니다.
# 92.95% 확률로 부정!! 리뷰입니다.
# 97.63% 확률로 부정!! 리뷰입니다.
# 89.80% 확률로 부정!! 리뷰입니다.
# 73.11% 확률로 부정!! 리뷰입니다.
# 94.29% 확률로 부정!! 리뷰입니다.
# 94.11% 확률로 부정!! 리뷰입니다.
# 93.78% 확률로 부정!! 리뷰입니다.
# 79.09% 확률로 부정!! 리뷰입니다.
# 74.55% 확률로 긍정^^ 리뷰입니다.
# 97.93% 확률로 부정!! 리뷰입니다.
# 97.44% 확률로 부정!! 리뷰입니다.
# 94.93% 확률로 부정!! 리뷰입니다.
# 75.52% 확률로 부정!! 리뷰입니다.
# 90.84% 확률로 긍정^^ 리뷰입니다.
# 98.63% 확률로 부정!! 리뷰입니다.
# 80.89% 확률로 부정!! 리뷰입니다.
# 96.77% 확률로 부정!! 리뷰입니다.
# 60.31% 확률로 긍정^^ 리뷰입니다.
# 85.99% 확률로 긍정^^ 리뷰입니다.
# 83.71% 확률로 부정!! 리뷰입니다.
# 83.70% 확률로 부정!! 리뷰입니다.
# 97.12% 확률로 부정!! 리뷰입니다.
# 90.83% 확률로 부정!! 리뷰입니다.
# 80.33% 확률로 부정!! 리뷰입니다.
# 96.89% 확률로 부정!! 리뷰입니다.
# 75.13% 확률로 긍정^^ 리뷰입니다.
# 91.21% 확률로 부정!! 리뷰입니다.
# 98.58% 확률로 부정!! 리뷰입니다.
# 91.27% 확률로 부정!! 리뷰입니다.
# 86.65% 확률로 부정!! 리뷰입니다.
# 72.66% 확률로 부정!! 리뷰입니다.
# 93.88% 확률로 부정!! 리뷰입니다.
# 56.85% 확률로 긍정^^ 리뷰입니다.
# 99.19% 확률로 부정!! 리뷰입니다.
# 95.22% 확률로 부정!! 리뷰입니다.
# 62.09% 확률로 부정!! 리뷰입니다.
# 98.88% 확률로 부정!! 리뷰입니다.
# 91.25% 확률로 부정!! 리뷰입니다.
# 88.45% 확률로 긍정^^ 리뷰입니다.
# 67.81% 확률로 긍정^^ 리뷰입니다.
# 89.11% 확률로 부정!! 리뷰입니다.
# 93.69% 확률로 부정!! 리뷰입니다.
# 92.31% 확률로 부정!! 리뷰입니다.
# 82.79% 확률로 부정!! 리뷰입니다.
# 98.22% 확률로 부정!! 리뷰입니다.
# 95.31% 확률로 부정!! 리뷰입니다.
# 87.92% 확률로 긍정^^ 리뷰입니다.
# 82.58% 확률로 부정!! 리뷰입니다.
# 98.00% 확률로 부정!! 리뷰입니다.
# 60.78% 확률로 긍정^^ 리뷰입니다.
# 97.96% 확률로 부정!! 리뷰입니다.
# 99.18% 확률로 부정!! 리뷰입니다.
# 50.23% 확률로 긍정^^ 리뷰입니다.
# 91.84% 확률로 부정!! 리뷰입니다.
# 86.39% 확률로 부정!! 리뷰입니다.
# 97.99% 확률로 부정!! 리뷰입니다.
# 64.66% 확률로 부정!! 리뷰입니다.
# 98.03% 확률로 부정!! 리뷰입니다.
# 79.50% 확률로 부정!! 리뷰입니다.
# 95.40% 확률로 부정!! 리뷰입니다.
# 97.17% 확률로 부정!! 리뷰입니다.
# 95.93% 확률로 부정!! 리뷰입니다.
# 96.29% 확률로 부정!! 리뷰입니다.
# 86.16% 확률로 부정!! 리뷰입니다.
# 98.70% 확률로 부정!! 리뷰입니다.
# 94.19% 확률로 부정!! 리뷰입니다.
# 92.51% 확률로 부정!! 리뷰입니다.
# 87.42% 확률로 부정!! 리뷰입니다.
# 95.33% 확률로 부정!! 리뷰입니다.
# 71.60% 확률로 부정!! 리뷰입니다.
# 98.90% 확률로 부정!! 리뷰입니다.
# 99.34% 확률로 부정!! 리뷰입니다.
# 91.63% 확률로 부정!! 리뷰입니다.
# 87.75% 확률로 긍정^^ 리뷰입니다.
# 92.32% 확률로 부정!! 리뷰입니다.
# 65.35% 확률로 부정!! 리뷰입니다.
# 96.77% 확률로 부정!! 리뷰입니다.
# 71.85% 확률로 부정!! 리뷰입니다.
# 82.05% 확률로 부정!! 리뷰입니다.
# 59.73% 확률로 부정!! 리뷰입니다.
# 60.28% 확률로 긍정^^ 리뷰입니다.
# 93.99% 확률로 부정!! 리뷰입니다.
# 87.51% 확률로 부정!! 리뷰입니다.
# 97.87% 확률로 부정!! 리뷰입니다.
# 93.05% 확률로 부정!! 리뷰입니다.
# 93.14% 확률로 부정!! 리뷰입니다.
# 98.94% 확률로 부정!! 리뷰입니다.
# 95.83% 확률로 부정!! 리뷰입니다.
# 82.57% 확률로 부정!! 리뷰입니다.
# 95.17% 확률로 부정!! 리뷰입니다.
# 99.71% 확률로 부정!! 리뷰입니다.
# 56.95% 확률로 부정!! 리뷰입니다.
# 97.08% 확률로 부정!! 리뷰입니다.
# 50.51% 확률로 긍정^^ 리뷰입니다.
# 86.72% 확률로 부정!! 리뷰입니다.
# 94.39% 확률로 부정!! 리뷰입니다.
# 75.46% 확률로 긍정^^ 리뷰입니다.
# 70.08% 확률로 부정!! 리뷰입니다.
# 99.10% 확률로 부정!! 리뷰입니다.
# 85.74% 확률로 부정!! 리뷰입니다.
# 52.77% 확률로 긍정^^ 리뷰입니다.
# 79.71% 확률로 부정!! 리뷰입니다.
# 98.89% 확률로 부정!! 리뷰입니다.
# 50.90% 확률로 부정!! 리뷰입니다.
# 80.91% 확률로 부정!! 리뷰입니다.
# 90.64% 확률로 부정!! 리뷰입니다.
# 71.31% 확률로 부정!! 리뷰입니다.
# 95.50% 확률로 부정!! 리뷰입니다.
# 93.61% 확률로 부정!! 리뷰입니다.
# 76.21% 확률로 긍정^^ 리뷰입니다.
# 99.03% 확률로 부정!! 리뷰입니다.
# 81.01% 확률로 부정!! 리뷰입니다.
# 51.97% 확률로 부정!! 리뷰입니다.
# 79.00% 확률로 부정!! 리뷰입니다.
# 86.13% 확률로 부정!! 리뷰입니다.
# 89.46% 확률로 부정!! 리뷰입니다.
# 79.95% 확률로 부정!! 리뷰입니다.
# 67.76% 확률로 긍정^^ 리뷰입니다.
# 63.18% 확률로 부정!! 리뷰입니다.
# 91.07% 확률로 긍정^^ 리뷰입니다.
# 69.30% 확률로 부정!! 리뷰입니다.
# 97.02% 확률로 긍정^^ 리뷰입니다.
# 89.42% 확률로 부정!! 리뷰입니다.
# 95.73% 확률로 부정!! 리뷰입니다.
# 64.41% 확률로 부정!! 리뷰입니다.
# 83.43% 확률로 부정!! 리뷰입니다.
# 62.09% 확률로 부정!! 리뷰입니다.
# 84.54% 확률로 부정!! 리뷰입니다.
# 94.85% 확률로 부정!! 리뷰입니다.
# 95.77% 확률로 부정!! 리뷰입니다.
# 65.53% 확률로 부정!! 리뷰입니다.
# 71.22% 확률로 부정!! 리뷰입니다.
# 94.49% 확률로 긍정^^ 리뷰입니다.
# 86.54% 확률로 부정!! 리뷰입니다.
# 97.69% 확률로 부정!! 리뷰입니다.
# 69.53% 확률로 긍정^^ 리뷰입니다.
# 97.24% 확률로 부정!! 리뷰입니다.
# 99.30% 확률로 부정!! 리뷰입니다.
# 60.84% 확률로 긍정^^ 리뷰입니다.
# 89.13% 확률로 부정!! 리뷰입니다.
# 61.82% 확률로 긍정^^ 리뷰입니다.
# 95.60% 확률로 부정!! 리뷰입니다.
# 79.02% 확률로 부정!! 리뷰입니다.
# 90.14% 확률로 부정!! 리뷰입니다.
# 99.81% 확률로 부정!! 리뷰입니다.
# 92.08% 확률로 부정!! 리뷰입니다.
# 88.48% 확률로 부정!! 리뷰입니다.
# 72.88% 확률로 부정!! 리뷰입니다.
# 95.41% 확률로 부정!! 리뷰입니다.
# 86.16% 확률로 부정!! 리뷰입니다.
# 72.63% 확률로 부정!! 리뷰입니다.
# 94.85% 확률로 부정!! 리뷰입니다.
# 97.87% 확률로 부정!! 리뷰입니다.
# 64.15% 확률로 부정!! 리뷰입니다.
# 97.11% 확률로 부정!! 리뷰입니다.
# 94.56% 확률로 부정!! 리뷰입니다.
# 77.56% 확률로 긍정^^ 리뷰입니다.
# 85.32% 확률로 부정!! 리뷰입니다.
# 85.38% 확률로 부정!! 리뷰입니다.
# 96.06% 확률로 부정!! 리뷰입니다.
# 91.81% 확률로 부정!! 리뷰입니다.
# 74.44% 확률로 부정!! 리뷰입니다.
# 97.34% 확률로 부정!! 리뷰입니다.
# 72.36% 확률로 긍정^^ 리뷰입니다.
# 95.23% 확률로 부정!! 리뷰입니다.
# 93.17% 확률로 부정!! 리뷰입니다.
# 83.41% 확률로 부정!! 리뷰입니다.
# 78.91% 확률로 부정!! 리뷰입니다.
# 86.39% 확률로 부정!! 리뷰입니다.
# 78.76% 확률로 부정!! 리뷰입니다.
# 89.05% 확률로 부정!! 리뷰입니다.
# 97.18% 확률로 부정!! 리뷰입니다.
# 65.23% 확률로 부정!! 리뷰입니다.
# 93.37% 확률로 부정!! 리뷰입니다.
# 95.50% 확률로 부정!! 리뷰입니다.
# 99.13% 확률로 긍정^^ 리뷰입니다.
# 98.03% 확률로 부정!! 리뷰입니다.
# 98.18% 확률로 부정!! 리뷰입니다.
# 97.32% 확률로 부정!! 리뷰입니다.
# 92.65% 확률로 부정!! 리뷰입니다.
# 55.55% 확률로 부정!! 리뷰입니다.
# 99.19% 확률로 부정!! 리뷰입니다.
# 96.33% 확률로 부정!! 리뷰입니다.
# 98.22% 확률로 부정!! 리뷰입니다.
# 85.23% 확률로 부정!! 리뷰입니다.
# 96.82% 확률로 부정!! 리뷰입니다.
# 97.90% 확률로 부정!! 리뷰입니다.
# 81.43% 확률로 부정!! 리뷰입니다.
# 83.22% 확률로 부정!! 리뷰입니다.
# 97.56% 확률로 부정!! 리뷰입니다.
# 58.25% 확률로 부정!! 리뷰입니다.
# 61.09% 확률로 부정!! 리뷰입니다.
# 64.41% 확률로 부정!! 리뷰입니다.
# 96.36% 확률로 부정!! 리뷰입니다.
# 84.24% 확률로 부정!! 리뷰입니다.
# 93.50% 확률로 부정!! 리뷰입니다.
# 98.23% 확률로 부정!! 리뷰입니다.
# 80.52% 확률로 부정!! 리뷰입니다.
# 96.98% 확률로 긍정^^ 리뷰입니다.
# 69.58% 확률로 부정!! 리뷰입니다.
# 98.86% 확률로 부정!! 리뷰입니다.
# 97.73% 확률로 부정!! 리뷰입니다.
# 91.79% 확률로 긍정^^ 리뷰입니다.
# 85.15% 확률로 부정!! 리뷰입니다.
# 97.15% 확률로 부정!! 리뷰입니다.
# 64.41% 확률로 부정!! 리뷰입니다.
# 84.48% 확률로 부정!! 리뷰입니다.
# 92.79% 확률로 부정!! 리뷰입니다.
# 85.79% 확률로 부정!! 리뷰입니다.
# 57.61% 확률로 부정!! 리뷰입니다.
# 99.60% 확률로 부정!! 리뷰입니다.
# 62.17% 확률로 부정!! 리뷰입니다.
# 96.06% 확률로 부정!! 리뷰입니다.
# 56.08% 확률로 부정!! 리뷰입니다.
# 61.75% 확률로 부정!! 리뷰입니다.
# 94.42% 확률로 부정!! 리뷰입니다.
# 77.71% 확률로 부정!! 리뷰입니다.
# 88.56% 확률로 부정!! 리뷰입니다.
# 88.73% 확률로 부정!! 리뷰입니다.
# 81.57% 확률로 긍정^^ 리뷰입니다.
# 60.62% 확률로 부정!! 리뷰입니다.
# 84.73% 확률로 부정!! 리뷰입니다.
# 91.12% 확률로 부정!! 리뷰입니다.
# 59.82% 확률로 부정!! 리뷰입니다.
# 99.33% 확률로 부정!! 리뷰입니다.
# 97.22% 확률로 부정!! 리뷰입니다.
# 94.57% 확률로 부정!! 리뷰입니다.
# 97.11% 확률로 부정!! 리뷰입니다.
# 58.52% 확률로 부정!! 리뷰입니다.
# 95.96% 확률로 부정!! 리뷰입니다.
# 85.99% 확률로 부정!! 리뷰입니다.
# 97.63% 확률로 부정!! 리뷰입니다.
# 61.44% 확률로 부정!! 리뷰입니다.
# 85.44% 확률로 긍정^^ 리뷰입니다.
# 56.31% 확률로 부정!! 리뷰입니다.
# 95.92% 확률로 부정!! 리뷰입니다.
# 92.48% 확률로 부정!! 리뷰입니다.
# 88.89% 확률로 부정!! 리뷰입니다.
# 90.12% 확률로 부정!! 리뷰입니다.
# 97.22% 확률로 부정!! 리뷰입니다.
# 69.48% 확률로 부정!! 리뷰입니다.
# 94.06% 확률로 부정!! 리뷰입니다.
# 84.34% 확률로 부정!! 리뷰입니다.
# 98.92% 확률로 부정!! 리뷰입니다.
# 88.02% 확률로 부정!! 리뷰입니다.
# 96.99% 확률로 부정!! 리뷰입니다.
# 61.78% 확률로 긍정^^ 리뷰입니다.
# 97.75% 확률로 부정!! 리뷰입니다.
# 65.16% 확률로 부정!! 리뷰입니다.
# 95.94% 확률로 부정!! 리뷰입니다.
# 83.09% 확률로 부정!! 리뷰입니다.
# 65.37% 확률로 긍정^^ 리뷰입니다.
# 67.98% 확률로 부정!! 리뷰입니다.
# 64.69% 확률로 긍정^^ 리뷰입니다.
# 95.84% 확률로 부정!! 리뷰입니다.
# 68.61% 확률로 긍정^^ 리뷰입니다.
# 99.20% 확률로 부정!! 리뷰입니다.
# 97.29% 확률로 부정!! 리뷰입니다.
# 63.81% 확률로 긍정^^ 리뷰입니다.
# 90.28% 확률로 부정!! 리뷰입니다.
# 96.24% 확률로 부정!! 리뷰입니다.
# 59.60% 확률로 부정!! 리뷰입니다.
# 76.03% 확률로 부정!! 리뷰입니다.
# 91.99% 확률로 부정!! 리뷰입니다.
# 84.99% 확률로 부정!! 리뷰입니다.
# 66.56% 확률로 긍정^^ 리뷰입니다.
# 99.32% 확률로 부정!! 리뷰입니다.
# 83.21% 확률로 부정!! 리뷰입니다.
# 93.14% 확률로 부정!! 리뷰입니다.
# 95.48% 확률로 부정!! 리뷰입니다.
# 63.29% 확률로 긍정^^ 리뷰입니다.
# 99.46% 확률로 부정!! 리뷰입니다.
# 82.27% 확률로 부정!! 리뷰입니다.
# 98.81% 확률로 부정!! 리뷰입니다.
# 98.23% 확률로 부정!! 리뷰입니다.
# 90.93% 확률로 부정!! 리뷰입니다.
# 98.96% 확률로 긍정^^ 리뷰입니다.
# 93.43% 확률로 부정!! 리뷰입니다.
# 89.79% 확률로 부정!! 리뷰입니다.
# 91.88% 확률로 부정!! 리뷰입니다.
# 89.15% 확률로 부정!! 리뷰입니다.
# 89.58% 확률로 부정!! 리뷰입니다.
# 91.61% 확률로 부정!! 리뷰입니다.
# 98.95% 확률로 부정!! 리뷰입니다.
# 85.17% 확률로 부정!! 리뷰입니다.
# 65.59% 확률로 긍정^^ 리뷰입니다.
# 97.55% 확률로 부정!! 리뷰입니다.
# 93.14% 확률로 부정!! 리뷰입니다.
# 99.10% 확률로 부정!! 리뷰입니다.
# 92.12% 확률로 부정!! 리뷰입니다.
# 97.57% 확률로 부정!! 리뷰입니다.
# 98.57% 확률로 부정!! 리뷰입니다.
# 98.11% 확률로 부정!! 리뷰입니다.
# 57.36% 확률로 부정!! 리뷰입니다.
# 97.67% 확률로 부정!! 리뷰입니다.
# 84.89% 확률로 부정!! 리뷰입니다.
# 94.69% 확률로 부정!! 리뷰입니다.
# 98.88% 확률로 부정!! 리뷰입니다.
# 96.22% 확률로 부정!! 리뷰입니다.
# 91.16% 확률로 부정!! 리뷰입니다.
# 99.36% 확률로 부정!! 리뷰입니다.
# 85.55% 확률로 부정!! 리뷰입니다.
# 99.42% 확률로 긍정^^ 리뷰입니다.
# 98.06% 확률로 긍정^^ 리뷰입니다.
# 67.17% 확률로 부정!! 리뷰입니다.
# 95.37% 확률로 부정!! 리뷰입니다.
# 71.16% 확률로 부정!! 리뷰입니다.
# 57.38% 확률로 긍정^^ 리뷰입니다.
# 68.68% 확률로 긍정^^ 리뷰입니다.
# 81.50% 확률로 부정!! 리뷰입니다.
# 88.19% 확률로 부정!! 리뷰입니다.
# 73.08% 확률로 부정!! 리뷰입니다.
# 79.58% 확률로 부정!! 리뷰입니다.
# 91.26% 확률로 부정!! 리뷰입니다.
# 91.08% 확률로 부정!! 리뷰입니다.
# 94.72% 확률로 부정!! 리뷰입니다.
# 67.79% 확률로 부정!! 리뷰입니다.
# 98.98% 확률로 부정!! 리뷰입니다.
# 96.17% 확률로 부정!! 리뷰입니다.
# 95.81% 확률로 부정!! 리뷰입니다.
# 95.74% 확률로 부정!! 리뷰입니다.
# 85.81% 확률로 부정!! 리뷰입니다.
# 98.04% 확률로 부정!! 리뷰입니다.
# 91.91% 확률로 부정!! 리뷰입니다.
# 62.53% 확률로 부정!! 리뷰입니다.
# 99.03% 확률로 부정!! 리뷰입니다.
# 88.40% 확률로 부정!! 리뷰입니다.
# 78.57% 확률로 긍정^^ 리뷰입니다.
# 87.48% 확률로 부정!! 리뷰입니다.
# 73.32% 확률로 부정!! 리뷰입니다.
# 91.56% 확률로 부정!! 리뷰입니다.
# 90.49% 확률로 부정!! 리뷰입니다.
# 67.80% 확률로 긍정^^ 리뷰입니다.
# 96.99% 확률로 부정!! 리뷰입니다.
# 90.55% 확률로 부정!! 리뷰입니다.
# 97.42% 확률로 부정!! 리뷰입니다.
# 63.48% 확률로 긍정^^ 리뷰입니다.
# 91.65% 확률로 부정!! 리뷰입니다.
# 53.21% 확률로 부정!! 리뷰입니다.
# 96.57% 확률로 부정!! 리뷰입니다.
# 75.38% 확률로 부정!! 리뷰입니다.
# 84.01% 확률로 긍정^^ 리뷰입니다.
# 92.72% 확률로 부정!! 리뷰입니다.
# 79.83% 확률로 부정!! 리뷰입니다.
# 95.01% 확률로 부정!! 리뷰입니다.
# 61.91% 확률로 긍정^^ 리뷰입니다.
# 94.99% 확률로 부정!! 리뷰입니다.
# 91.99% 확률로 부정!! 리뷰입니다.
# 96.78% 확률로 부정!! 리뷰입니다.
# 64.41% 확률로 부정!! 리뷰입니다.
# 72.16% 확률로 긍정^^ 리뷰입니다.
# 92.77% 확률로 부정!! 리뷰입니다.
# 92.94% 확률로 부정!! 리뷰입니다.
# 99.51% 확률로 부정!! 리뷰입니다.
# 97.53% 확률로 부정!! 리뷰입니다.
# 94.56% 확률로 부정!! 리뷰입니다.
# 78.63% 확률로 긍정^^ 리뷰입니다.
# 68.58% 확률로 부정!! 리뷰입니다.
# 92.62% 확률로 부정!! 리뷰입니다.
# 98.32% 확률로 부정!! 리뷰입니다.
# 85.00% 확률로 부정!! 리뷰입니다.
# 98.55% 확률로 부정!! 리뷰입니다.
# 96.24% 확률로 부정!! 리뷰입니다.
# 82.16% 확률로 긍정^^ 리뷰입니다.
# 99.81% 확률로 부정!! 리뷰입니다.
# 89.83% 확률로 부정!! 리뷰입니다.
# 98.66% 확률로 부정!! 리뷰입니다.
# 59.67% 확률로 부정!! 리뷰입니다.
# 98.27% 확률로 부정!! 리뷰입니다.
# 58.70% 확률로 부정!! 리뷰입니다.
# 84.22% 확률로 부정!! 리뷰입니다.
# 99.33% 확률로 부정!! 리뷰입니다.
# 98.92% 확률로 긍정^^ 리뷰입니다.
# 96.64% 확률로 긍정^^ 리뷰입니다.
# 99.18% 확률로 부정!! 리뷰입니다.
# 89.41% 확률로 긍정^^ 리뷰입니다.
# 63.35% 확률로 긍정^^ 리뷰입니다.
# 94.51% 확률로 부정!! 리뷰입니다.
# 62.09% 확률로 부정!! 리뷰입니다.
# 70.77% 확률로 부정!! 리뷰입니다.
# 94.14% 확률로 부정!! 리뷰입니다.
# 97.87% 확률로 부정!! 리뷰입니다.
# 80.83% 확률로 부정!! 리뷰입니다.
# 95.00% 확률로 부정!! 리뷰입니다.
# 87.44% 확률로 부정!! 리뷰입니다.
# 98.10% 확률로 부정!! 리뷰입니다.
# 82.99% 확률로 부정!! 리뷰입니다.
# 98.54% 확률로 부정!! 리뷰입니다.
# 59.15% 확률로 긍정^^ 리뷰입니다.
# 76.67% 확률로 부정!! 리뷰입니다.
# 90.45% 확률로 부정!! 리뷰입니다.
# 96.48% 확률로 부정!! 리뷰입니다.
# 99.76% 확률로 부정!! 리뷰입니다.
# 94.64% 확률로 부정!! 리뷰입니다.
# 95.55% 확률로 부정!! 리뷰입니다.
# 88.03% 확률로 부정!! 리뷰입니다.
# 56.97% 확률로 긍정^^ 리뷰입니다.
# 88.59% 확률로 부정!! 리뷰입니다.
# 96.24% 확률로 부정!! 리뷰입니다.
# 98.41% 확률로 부정!! 리뷰입니다.
# 76.48% 확률로 부정!! 리뷰입니다.
# 92.58% 확률로 부정!! 리뷰입니다.
# 89.51% 확률로 부정!! 리뷰입니다.
# 97.40% 확률로 부정!! 리뷰입니다.
# 95.21% 확률로 부정!! 리뷰입니다.
# 99.20% 확률로 부정!! 리뷰입니다.
# 95.48% 확률로 부정!! 리뷰입니다.
# 59.72% 확률로 부정!! 리뷰입니다.
# 95.37% 확률로 부정!! 리뷰입니다.
# 88.78% 확률로 부정!! 리뷰입니다.
# 92.29% 확률로 부정!! 리뷰입니다.
# 94.90% 확률로 부정!! 리뷰입니다.
# 64.61% 확률로 부정!! 리뷰입니다.
# 98.52% 확률로 부정!! 리뷰입니다.
# 70.09% 확률로 부정!! 리뷰입니다.
# 97.55% 확률로 부정!! 리뷰입니다.
# 99.28% 확률로 부정!! 리뷰입니다.
# 74.16% 확률로 부정!! 리뷰입니다.
# 95.13% 확률로 긍정^^ 리뷰입니다.
# 97.35% 확률로 부정!! 리뷰입니다.
# 89.75% 확률로 부정!! 리뷰입니다.
# 62.74% 확률로 부정!! 리뷰입니다.
# 99.35% 확률로 부정!! 리뷰입니다.
# 63.06% 확률로 긍정^^ 리뷰입니다.
# 52.42% 확률로 부정!! 리뷰입니다.
# 87.48% 확률로 부정!! 리뷰입니다.
# 95.10% 확률로 부정!! 리뷰입니다.
# 80.09% 확률로 긍정^^ 리뷰입니다.
# 95.77% 확률로 부정!! 리뷰입니다.
# 93.93% 확률로 부정!! 리뷰입니다.
# 89.82% 확률로 부정!! 리뷰입니다.
# 58.34% 확률로 부정!! 리뷰입니다.
# 95.46% 확률로 부정!! 리뷰입니다.
# 92.27% 확률로 부정!! 리뷰입니다.
# 81.61% 확률로 부정!! 리뷰입니다.
# 93.55% 확률로 부정!! 리뷰입니다.
# 71.46% 확률로 부정!! 리뷰입니다.
# 97.23% 확률로 부정!! 리뷰입니다.
# 60.95% 확률로 부정!! 리뷰입니다.
# 68.41% 확률로 긍정^^ 리뷰입니다.
# 86.83% 확률로 부정!! 리뷰입니다.
# 99.45% 확률로 부정!! 리뷰입니다.
# 93.52% 확률로 부정!! 리뷰입니다.
# 82.32% 확률로 부정!! 리뷰입니다.
# 98.20% 확률로 부정!! 리뷰입니다.
# 94.00% 확률로 부정!! 리뷰입니다.
# 82.58% 확률로 부정!! 리뷰입니다.
# 96.88% 확률로 부정!! 리뷰입니다.
# 85.97% 확률로 부정!! 리뷰입니다.
# 91.51% 확률로 부정!! 리뷰입니다.
# 61.65% 확률로 부정!! 리뷰입니다.
# 79.84% 확률로 부정!! 리뷰입니다.
# 97.19% 확률로 부정!! 리뷰입니다.
# 77.96% 확률로 부정!! 리뷰입니다.
# 93.63% 확률로 부정!! 리뷰입니다.
# 95.57% 확률로 부정!! 리뷰입니다.
# 95.65% 확률로 부정!! 리뷰입니다.
# 97.77% 확률로 부정!! 리뷰입니다.
# 96.26% 확률로 부정!! 리뷰입니다.
# 98.57% 확률로 부정!! 리뷰입니다.
# 77.74% 확률로 긍정^^ 리뷰입니다.
# 83.62% 확률로 부정!! 리뷰입니다.
# 99.38% 확률로 부정!! 리뷰입니다.
# 65.03% 확률로 긍정^^ 리뷰입니다.
# 51.21% 확률로 긍정^^ 리뷰입니다.
# 95.87% 확률로 부정!! 리뷰입니다.
# 59.26% 확률로 부정!! 리뷰입니다.
# 98.90% 확률로 부정!! 리뷰입니다.
# 79.33% 확률로 부정!! 리뷰입니다.
# 66.02% 확률로 부정!! 리뷰입니다.
# 96.71% 확률로 부정!! 리뷰입니다.
# 80.10% 확률로 부정!! 리뷰입니다.
# 97.72% 확률로 부정!! 리뷰입니다.
# 96.27% 확률로 부정!! 리뷰입니다.
# 92.88% 확률로 부정!! 리뷰입니다.
# 96.02% 확률로 부정!! 리뷰입니다.
# 96.15% 확률로 부정!! 리뷰입니다.
# 82.33% 확률로 부정!! 리뷰입니다.
# 96.25% 확률로 부정!! 리뷰입니다.
# 69.94% 확률로 긍정^^ 리뷰입니다.
# 99.77% 확률로 부정!! 리뷰입니다.
# 93.35% 확률로 부정!! 리뷰입니다.
# 96.60% 확률로 부정!! 리뷰입니다.
# 97.37% 확률로 부정!! 리뷰입니다.
# 97.84% 확률로 부정!! 리뷰입니다.
# 99.21% 확률로 부정!! 리뷰입니다.
# 93.89% 확률로 부정!! 리뷰입니다.
# 83.12% 확률로 부정!! 리뷰입니다.
# 95.53% 확률로 부정!! 리뷰입니다.
# 99.11% 확률로 부정!! 리뷰입니다.
# 77.50% 확률로 부정!! 리뷰입니다.
# 95.35% 확률로 부정!! 리뷰입니다.
# 54.50% 확률로 긍정^^ 리뷰입니다.
# 94.75% 확률로 부정!! 리뷰입니다.
# 96.72% 확률로 부정!! 리뷰입니다.
# 92.50% 확률로 부정!! 리뷰입니다.
# 97.02% 확률로 부정!! 리뷰입니다.
# 89.06% 확률로 부정!! 리뷰입니다.
# 83.03% 확률로 부정!! 리뷰입니다.
# 95.10% 확률로 부정!! 리뷰입니다.
# 98.46% 확률로 부정!! 리뷰입니다.
# 64.41% 확률로 부정!! 리뷰입니다.
# 99.25% 확률로 부정!! 리뷰입니다.
# 98.70% 확률로 부정!! 리뷰입니다.
# 72.94% 확률로 부정!! 리뷰입니다.
# 84.52% 확률로 부정!! 리뷰입니다.
# 87.43% 확률로 부정!! 리뷰입니다.
# 97.21% 확률로 부정!! 리뷰입니다.
# 63.51% 확률로 긍정^^ 리뷰입니다.
# 81.00% 확률로 부정!! 리뷰입니다.
# 93.29% 확률로 부정!! 리뷰입니다.
# 91.30% 확률로 부정!! 리뷰입니다.
# 98.48% 확률로 부정!! 리뷰입니다.
# 97.95% 확률로 부정!! 리뷰입니다.
# 79.57% 확률로 부정!! 리뷰입니다.
# 98.44% 확률로 부정!! 리뷰입니다.
# 96.39% 확률로 부정!! 리뷰입니다.
# 60.37% 확률로 부정!! 리뷰입니다.
# 97.34% 확률로 부정!! 리뷰입니다.
# 92.89% 확률로 부정!! 리뷰입니다.
# 98.60% 확률로 부정!! 리뷰입니다.
# 98.05% 확률로 부정!! 리뷰입니다.
# 95.19% 확률로 부정!! 리뷰입니다.
# 80.31% 확률로 부정!! 리뷰입니다.
# 98.27% 확률로 부정!! 리뷰입니다.
# 62.66% 확률로 부정!! 리뷰입니다.
# 87.71% 확률로 부정!! 리뷰입니다.
# 85.30% 확률로 부정!! 리뷰입니다.
# 98.88% 확률로 부정!! 리뷰입니다.
# 99.64% 확률로 부정!! 리뷰입니다.
# 96.64% 확률로 부정!! 리뷰입니다.
# 98.90% 확률로 부정!! 리뷰입니다.
# 99.30% 확률로 부정!! 리뷰입니다.
# 97.06% 확률로 부정!! 리뷰입니다.
# 72.14% 확률로 부정!! 리뷰입니다.
# 67.68% 확률로 부정!! 리뷰입니다.
# 93.08% 확률로 부정!! 리뷰입니다.
# 92.87% 확률로 부정!! 리뷰입니다.
# 97.92% 확률로 부정!! 리뷰입니다.
# 86.17% 확률로 부정!! 리뷰입니다.
# 98.08% 확률로 부정!! 리뷰입니다.
# 94.58% 확률로 부정!! 리뷰입니다.
# 96.76% 확률로 부정!! 리뷰입니다.
# 81.05% 확률로 부정!! 리뷰입니다.
# 55.17% 확률로 부정!! 리뷰입니다.
# 64.18% 확률로 긍정^^ 리뷰입니다.
# 90.74% 확률로 부정!! 리뷰입니다.
# 69.86% 확률로 긍정^^ 리뷰입니다.
# 66.18% 확률로 긍정^^ 리뷰입니다.
# 97.49% 확률로 부정!! 리뷰입니다.
# 99.02% 확률로 부정!! 리뷰입니다.
# 50.67% 확률로 부정!! 리뷰입니다.
# 97.16% 확률로 부정!! 리뷰입니다.
# 94.48% 확률로 부정!! 리뷰입니다.
# 99.27% 확률로 긍정^^ 리뷰입니다.
# 73.09% 확률로 긍정^^ 리뷰입니다.
# 97.21% 확률로 부정!! 리뷰입니다.
# 99.07% 확률로 부정!! 리뷰입니다.
# 84.86% 확률로 긍정^^ 리뷰입니다.
# 92.27% 확률로 부정!! 리뷰입니다.
# 95.53% 확률로 부정!! 리뷰입니다.
# 97.53% 확률로 부정!! 리뷰입니다.
# 84.47% 확률로 긍정^^ 리뷰입니다.
# 95.00% 확률로 부정!! 리뷰입니다.
# 88.16% 확률로 긍정^^ 리뷰입니다.
# 99.63% 확률로 부정!! 리뷰입니다.
# 98.93% 확률로 부정!! 리뷰입니다.
# 94.97% 확률로 부정!! 리뷰입니다.
# 97.59% 확률로 부정!! 리뷰입니다.
# 80.39% 확률로 긍정^^ 리뷰입니다.
# 95.84% 확률로 부정!! 리뷰입니다.
# 93.88% 확률로 긍정^^ 리뷰입니다.
# 59.13% 확률로 부정!! 리뷰입니다.
